# %%
import novagraph as nova
from json import load

# %% [markdown]
# ## 1. Visual Analytics in Notebooks
#
# We can directly use `nova.visualize()` to visualize a graph (loaded from a JSON file) with default configurations.

# %%
# Read the data
miserables = load(open('./miserables.json', 'r'))

# Pass data to our VA tool and show it below the cell
nova.visualize(miserables)
# Out:
#         <iframe
#             srcdoc="&lt;!doctype html&gt;&lt;html lang=&quot;en&quot;&gt;&lt;head&gt;&lt;meta charset=&quot;utf-8&quot;/&gt;&lt;link rel=&quot;icon&quot; href=&quot;/favicon.ico&quot;/&gt;&lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,initial-scale=1&quot;/&gt;&lt;meta name=&quot;theme-color&quot; content=&quot;#000000&quot;/&gt;&lt;meta name=&quot;description&quot; content=&quot;Web site created using create-react-app&quot;/&gt;&lt;link rel=&quot;apple-touch-icon&quot; href=&quot;/logo192.png&quot;/&gt;&lt;link rel=&quot;manifest&quot; href=&quot;/manifest.json&quot;/&gt;&lt;title&gt;React App&lt;/title&gt;&lt;style&gt;html{font-size:16px;-moz-osx-font-smoothing:grayscale;-webkit-font-smoothing:antialiased;text-rendering:optimizeLegibility;-webkit-text-size-adjust:100%;-moz-text-size-adjust:100%;scroll-behavior:smooth}body,html{position:relative;width:100%;height:100%}body{margin:0;padding:0;box-sizing:border-box;font-family:-apple-system,BlinkMacSystemFont,&quot;Segoe UI&quot;,Roboto,Oxygen-Sans,Ubuntu,Cantarell,&quot;Helvetica Neue&quot;,sans-serif;color:#4a4a4a;font-size:1em;font-weight:400;line-height:1.5}*,:after,:before{box-sizing:inherit}a{color:#0064c8;text-decoration:none}a:hover{text-decoration:underline}a:visited{color:#0050a0}:root{--ease-cubic-in-out:cubic-bezier(0.645,0.045,0.355,1);--md-red-50:#ffebee;--md-red-100:#ffcdd2;--md-red-200:#ef9a9a;--md-red-300:#e57373;--md-red-400:#ef5350;--md-red-500:#f44336;--md-red-600:#e53835;--md-red-700:#d32f2f;--md-red-800:#c62828;--md-red-900:#b71c1c;--md-red-a100:#ff8880;--md-red-a200:#ff5252;--md-red-a400:#ff1745;--md-red-a700:#d50000;--md-pink-50:#fce4ec;--md-pink-100:#f8bbd0;--md-pink-200:#f48fb2;--md-pink-300:#f06294;--md-pink-400:#ec407c;--md-pink-500:#e91e65;--md-pink-600:#d81b60;--md-pink-700:#c2185c;--md-pink-800:#ad1459;--md-pink-900:#880e4f;--md-pink-a100:#ff80ac;--md-pink-a200:#ff4083;--md-pink-a400:#f5005a;--md-pink-a700:#c51162;--md-purple-50:#f3e5f5;--md-purple-100:#e1bee7;--md-purple-200:#ce93d8;--md-purple-300:#ba68c8;--md-purple-400:#aa47bc;--md-purple-500:#9b27b0;--md-purple-600:#8d24aa;--md-purple-700:#7b1fa2;--md-purple-800:#691b9a;--md-purple-900:#4a148c;--md-purple-a100:#e980fc;--md-purple-a200:#df40fb;--md-purple-a400:#d400f9;--md-purple-a700:#a0f;--md-deep-purple-50:#ede7f6;--md-deep-purple-100:#d1c4e9;--md-deep-purple-200:#b39ddb;--md-deep-purple-300:#9475cd;--md-deep-purple-400:#7c57c2;--md-deep-purple-500:#663ab7;--md-deep-purple-600:#5c35b1;--md-deep-purple-700:#502da8;--md-deep-purple-800:#4327a0;--md-deep-purple-900:#311b92;--md-deep-purple-a100:#b288ff;--md-deep-purple-a200:#7a4dff;--md-deep-purple-a400:#621fff;--md-deep-purple-a700:#6100ea;--md-indigo-50:#e8eaf6;--md-indigo-100:#c5cae9;--md-indigo-200:#9fa9da;--md-indigo-300:#7987cb;--md-indigo-400:#5c6dc0;--md-indigo-500:#3f53b5;--md-indigo-600:#394aab;--md-indigo-700:#30419f;--md-indigo-800:#283693;--md-indigo-900:#1a247e;--md-indigo-a100:#8c9fff;--md-indigo-a200:#5370fe;--md-indigo-a400:#3d5dfe;--md-indigo-a700:#3052fe;--md-blue-50:#e3f2fd;--md-blue-100:#bbdefb;--md-blue-200:#90ccf9;--md-blue-300:#64b7f6;--md-blue-400:#42a7f5;--md-blue-500:#2198f3;--md-blue-600:#1e88e5;--md-blue-700:#1979d2;--md-blue-800:#1568c0;--md-blue-900:#0d48a1;--md-blue-a100:#82b2ff;--md-blue-a200:#448cff;--md-blue-a400:#297bff;--md-blue-a700:#2962ff;--md-light-blue-50:#e1f5fe;--md-light-blue-100:#b3e6fc;--md-light-blue-200:#81d6fa;--md-light-blue-300:#4fc5f7;--md-light-blue-400:#29b8f6;--md-light-blue-500:#03acf4;--md-light-blue-600:#039de5;--md-light-blue-700:#0289d1;--md-light-blue-800:#0278bd;--md-light-blue-900:#01589b;--md-light-blue-a100:#80d9ff;--md-light-blue-a200:#40c6ff;--md-light-blue-a400:#00b2ff;--md-light-blue-a700:#0094ea;--md-cyan-50:#e0f7fa;--md-cyan-100:#b2ecf2;--md-cyan-200:#80dfea;--md-cyan-300:#4dd2e1;--md-cyan-400:#26c8da;--md-cyan-500:#00bfd4;--md-cyan-600:#00aec1;--md-cyan-700:#0099a7;--md-cyan-800:#00838f;--md-cyan-900:#006164;--md-cyan-a100:#84ffff;--md-cyan-a200:#18ff ...

# %% [markdown]
# ## 2. Customized Visual Analytics
#
# We can also pass argumetns into `nova.visualize()` to create a customized VA tool. We can control the size of the graph view and initial force layout strengths.
#
# Run `?nova.visualize` to see all parameters.

# %%
# ?nova.visualize

# %%
nova.visualize(miserables, width=400, height=420, node_strength=-20)
# Out:
#         <iframe
#             srcdoc="&lt;!doctype html&gt;&lt;html lang=&quot;en&quot;&gt;&lt;head&gt;&lt;meta charset=&quot;utf-8&quot;/&gt;&lt;link rel=&quot;icon&quot; href=&quot;/favicon.ico&quot;/&gt;&lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,initial-scale=1&quot;/&gt;&lt;meta name=&quot;theme-color&quot; content=&quot;#000000&quot;/&gt;&lt;meta name=&quot;description&quot; content=&quot;Web site created using create-react-app&quot;/&gt;&lt;link rel=&quot;apple-touch-icon&quot; href=&quot;/logo192.png&quot;/&gt;&lt;link rel=&quot;manifest&quot; href=&quot;/manifest.json&quot;/&gt;&lt;title&gt;React App&lt;/title&gt;&lt;style&gt;html{font-size:16px;-moz-osx-font-smoothing:grayscale;-webkit-font-smoothing:antialiased;text-rendering:optimizeLegibility;-webkit-text-size-adjust:100%;-moz-text-size-adjust:100%;scroll-behavior:smooth}body,html{position:relative;width:100%;height:100%}body{margin:0;padding:0;box-sizing:border-box;font-family:-apple-system,BlinkMacSystemFont,&quot;Segoe UI&quot;,Roboto,Oxygen-Sans,Ubuntu,Cantarell,&quot;Helvetica Neue&quot;,sans-serif;color:#4a4a4a;font-size:1em;font-weight:400;line-height:1.5}*,:after,:before{box-sizing:inherit}a{color:#0064c8;text-decoration:none}a:hover{text-decoration:underline}a:visited{color:#0050a0}:root{--ease-cubic-in-out:cubic-bezier(0.645,0.045,0.355,1);--md-red-50:#ffebee;--md-red-100:#ffcdd2;--md-red-200:#ef9a9a;--md-red-300:#e57373;--md-red-400:#ef5350;--md-red-500:#f44336;--md-red-600:#e53835;--md-red-700:#d32f2f;--md-red-800:#c62828;--md-red-900:#b71c1c;--md-red-a100:#ff8880;--md-red-a200:#ff5252;--md-red-a400:#ff1745;--md-red-a700:#d50000;--md-pink-50:#fce4ec;--md-pink-100:#f8bbd0;--md-pink-200:#f48fb2;--md-pink-300:#f06294;--md-pink-400:#ec407c;--md-pink-500:#e91e65;--md-pink-600:#d81b60;--md-pink-700:#c2185c;--md-pink-800:#ad1459;--md-pink-900:#880e4f;--md-pink-a100:#ff80ac;--md-pink-a200:#ff4083;--md-pink-a400:#f5005a;--md-pink-a700:#c51162;--md-purple-50:#f3e5f5;--md-purple-100:#e1bee7;--md-purple-200:#ce93d8;--md-purple-300:#ba68c8;--md-purple-400:#aa47bc;--md-purple-500:#9b27b0;--md-purple-600:#8d24aa;--md-purple-700:#7b1fa2;--md-purple-800:#691b9a;--md-purple-900:#4a148c;--md-purple-a100:#e980fc;--md-purple-a200:#df40fb;--md-purple-a400:#d400f9;--md-purple-a700:#a0f;--md-deep-purple-50:#ede7f6;--md-deep-purple-100:#d1c4e9;--md-deep-purple-200:#b39ddb;--md-deep-purple-300:#9475cd;--md-deep-purple-400:#7c57c2;--md-deep-purple-500:#663ab7;--md-deep-purple-600:#5c35b1;--md-deep-purple-700:#502da8;--md-deep-purple-800:#4327a0;--md-deep-purple-900:#311b92;--md-deep-purple-a100:#b288ff;--md-deep-purple-a200:#7a4dff;--md-deep-purple-a400:#621fff;--md-deep-purple-a700:#6100ea;--md-indigo-50:#e8eaf6;--md-indigo-100:#c5cae9;--md-indigo-200:#9fa9da;--md-indigo-300:#7987cb;--md-indigo-400:#5c6dc0;--md-indigo-500:#3f53b5;--md-indigo-600:#394aab;--md-indigo-700:#30419f;--md-indigo-800:#283693;--md-indigo-900:#1a247e;--md-indigo-a100:#8c9fff;--md-indigo-a200:#5370fe;--md-indigo-a400:#3d5dfe;--md-indigo-a700:#3052fe;--md-blue-50:#e3f2fd;--md-blue-100:#bbdefb;--md-blue-200:#90ccf9;--md-blue-300:#64b7f6;--md-blue-400:#42a7f5;--md-blue-500:#2198f3;--md-blue-600:#1e88e5;--md-blue-700:#1979d2;--md-blue-800:#1568c0;--md-blue-900:#0d48a1;--md-blue-a100:#82b2ff;--md-blue-a200:#448cff;--md-blue-a400:#297bff;--md-blue-a700:#2962ff;--md-light-blue-50:#e1f5fe;--md-light-blue-100:#b3e6fc;--md-light-blue-200:#81d6fa;--md-light-blue-300:#4fc5f7;--md-light-blue-400:#29b8f6;--md-light-blue-500:#03acf4;--md-light-blue-600:#039de5;--md-light-blue-700:#0289d1;--md-light-blue-800:#0278bd;--md-light-blue-900:#01589b;--md-light-blue-a100:#80d9ff;--md-light-blue-a200:#40c6ff;--md-light-blue-a400:#00b2ff;--md-light-blue-a700:#0094ea;--md-cyan-50:#e0f7fa;--md-cyan-100:#b2ecf2;--md-cyan-200:#80dfea;--md-cyan-300:#4dd2e1;--md-cyan-400:#26c8da;--md-cyan-500:#00bfd4;--md-cyan-600:#00aec1;--md-cyan-700:#0099a7;--md-cyan-800:#00838f;--md-cyan-900:#006164;--md-cyan-a100:#84ffff;--md-cyan-a200:#18ff ...

# %%
nova.visualize(miserables, width=800, height=820, node_strength=-90)
# Out:
#         <iframe
#             srcdoc="&lt;!doctype html&gt;&lt;html lang=&quot;en&quot;&gt;&lt;head&gt;&lt;meta charset=&quot;utf-8&quot;/&gt;&lt;link rel=&quot;icon&quot; href=&quot;/favicon.ico&quot;/&gt;&lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,initial-scale=1&quot;/&gt;&lt;meta name=&quot;theme-color&quot; content=&quot;#000000&quot;/&gt;&lt;meta name=&quot;description&quot; content=&quot;Web site created using create-react-app&quot;/&gt;&lt;link rel=&quot;apple-touch-icon&quot; href=&quot;/logo192.png&quot;/&gt;&lt;link rel=&quot;manifest&quot; href=&quot;/manifest.json&quot;/&gt;&lt;title&gt;React App&lt;/title&gt;&lt;style&gt;html{font-size:16px;-moz-osx-font-smoothing:grayscale;-webkit-font-smoothing:antialiased;text-rendering:optimizeLegibility;-webkit-text-size-adjust:100%;-moz-text-size-adjust:100%;scroll-behavior:smooth}body,html{position:relative;width:100%;height:100%}body{margin:0;padding:0;box-sizing:border-box;font-family:-apple-system,BlinkMacSystemFont,&quot;Segoe UI&quot;,Roboto,Oxygen-Sans,Ubuntu,Cantarell,&quot;Helvetica Neue&quot;,sans-serif;color:#4a4a4a;font-size:1em;font-weight:400;line-height:1.5}*,:after,:before{box-sizing:inherit}a{color:#0064c8;text-decoration:none}a:hover{text-decoration:underline}a:visited{color:#0050a0}:root{--ease-cubic-in-out:cubic-bezier(0.645,0.045,0.355,1);--md-red-50:#ffebee;--md-red-100:#ffcdd2;--md-red-200:#ef9a9a;--md-red-300:#e57373;--md-red-400:#ef5350;--md-red-500:#f44336;--md-red-600:#e53835;--md-red-700:#d32f2f;--md-red-800:#c62828;--md-red-900:#b71c1c;--md-red-a100:#ff8880;--md-red-a200:#ff5252;--md-red-a400:#ff1745;--md-red-a700:#d50000;--md-pink-50:#fce4ec;--md-pink-100:#f8bbd0;--md-pink-200:#f48fb2;--md-pink-300:#f06294;--md-pink-400:#ec407c;--md-pink-500:#e91e65;--md-pink-600:#d81b60;--md-pink-700:#c2185c;--md-pink-800:#ad1459;--md-pink-900:#880e4f;--md-pink-a100:#ff80ac;--md-pink-a200:#ff4083;--md-pink-a400:#f5005a;--md-pink-a700:#c51162;--md-purple-50:#f3e5f5;--md-purple-100:#e1bee7;--md-purple-200:#ce93d8;--md-purple-300:#ba68c8;--md-purple-400:#aa47bc;--md-purple-500:#9b27b0;--md-purple-600:#8d24aa;--md-purple-700:#7b1fa2;--md-purple-800:#691b9a;--md-purple-900:#4a148c;--md-purple-a100:#e980fc;--md-purple-a200:#df40fb;--md-purple-a400:#d400f9;--md-purple-a700:#a0f;--md-deep-purple-50:#ede7f6;--md-deep-purple-100:#d1c4e9;--md-deep-purple-200:#b39ddb;--md-deep-purple-300:#9475cd;--md-deep-purple-400:#7c57c2;--md-deep-purple-500:#663ab7;--md-deep-purple-600:#5c35b1;--md-deep-purple-700:#502da8;--md-deep-purple-800:#4327a0;--md-deep-purple-900:#311b92;--md-deep-purple-a100:#b288ff;--md-deep-purple-a200:#7a4dff;--md-deep-purple-a400:#621fff;--md-deep-purple-a700:#6100ea;--md-indigo-50:#e8eaf6;--md-indigo-100:#c5cae9;--md-indigo-200:#9fa9da;--md-indigo-300:#7987cb;--md-indigo-400:#5c6dc0;--md-indigo-500:#3f53b5;--md-indigo-600:#394aab;--md-indigo-700:#30419f;--md-indigo-800:#283693;--md-indigo-900:#1a247e;--md-indigo-a100:#8c9fff;--md-indigo-a200:#5370fe;--md-indigo-a400:#3d5dfe;--md-indigo-a700:#3052fe;--md-blue-50:#e3f2fd;--md-blue-100:#bbdefb;--md-blue-200:#90ccf9;--md-blue-300:#64b7f6;--md-blue-400:#42a7f5;--md-blue-500:#2198f3;--md-blue-600:#1e88e5;--md-blue-700:#1979d2;--md-blue-800:#1568c0;--md-blue-900:#0d48a1;--md-blue-a100:#82b2ff;--md-blue-a200:#448cff;--md-blue-a400:#297bff;--md-blue-a700:#2962ff;--md-light-blue-50:#e1f5fe;--md-light-blue-100:#b3e6fc;--md-light-blue-200:#81d6fa;--md-light-blue-300:#4fc5f7;--md-light-blue-400:#29b8f6;--md-light-blue-500:#03acf4;--md-light-blue-600:#039de5;--md-light-blue-700:#0289d1;--md-light-blue-800:#0278bd;--md-light-blue-900:#01589b;--md-light-blue-a100:#80d9ff;--md-light-blue-a200:#40c6ff;--md-light-blue-a400:#00b2ff;--md-light-blue-a700:#0094ea;--md-cyan-50:#e0f7fa;--md-cyan-100:#b2ecf2;--md-cyan-200:#80dfea;--md-cyan-300:#4dd2e1;--md-cyan-400:#26c8da;--md-cyan-500:#00bfd4;--md-cyan-600:#00aec1;--md-cyan-700:#0099a7;--md-cyan-800:#00838f;--md-cyan-900:#006164;--md-cyan-a100:#84ffff;--md-cyan-a200:#18ff ...

# %% [markdown]
# ## 3. Different Datasets
#
# We can pass different datasets into this simple VA tool through the first argument of `nova.visualize()`.

# %%
stackoverflow = load(open('./stackoverflow.json', 'r'))
nova.visualize(
    stackoverflow,
    width=400,
    height=420,
    node_strength=-10,
    link_strength=4
)
# Out:
#         <iframe
#             srcdoc="&lt;!doctype html&gt;&lt;html lang=&quot;en&quot;&gt;&lt;head&gt;&lt;meta charset=&quot;utf-8&quot;/&gt;&lt;link rel=&quot;icon&quot; href=&quot;/favicon.ico&quot;/&gt;&lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,initial-scale=1&quot;/&gt;&lt;meta name=&quot;theme-color&quot; content=&quot;#000000&quot;/&gt;&lt;meta name=&quot;description&quot; content=&quot;Web site created using create-react-app&quot;/&gt;&lt;link rel=&quot;apple-touch-icon&quot; href=&quot;/logo192.png&quot;/&gt;&lt;link rel=&quot;manifest&quot; href=&quot;/manifest.json&quot;/&gt;&lt;title&gt;React App&lt;/title&gt;&lt;style&gt;html{font-size:16px;-moz-osx-font-smoothing:grayscale;-webkit-font-smoothing:antialiased;text-rendering:optimizeLegibility;-webkit-text-size-adjust:100%;-moz-text-size-adjust:100%;scroll-behavior:smooth}body,html{position:relative;width:100%;height:100%}body{margin:0;padding:0;box-sizing:border-box;font-family:-apple-system,BlinkMacSystemFont,&quot;Segoe UI&quot;,Roboto,Oxygen-Sans,Ubuntu,Cantarell,&quot;Helvetica Neue&quot;,sans-serif;color:#4a4a4a;font-size:1em;font-weight:400;line-height:1.5}*,:after,:before{box-sizing:inherit}a{color:#0064c8;text-decoration:none}a:hover{text-decoration:underline}a:visited{color:#0050a0}:root{--ease-cubic-in-out:cubic-bezier(0.645,0.045,0.355,1);--md-red-50:#ffebee;--md-red-100:#ffcdd2;--md-red-200:#ef9a9a;--md-red-300:#e57373;--md-red-400:#ef5350;--md-red-500:#f44336;--md-red-600:#e53835;--md-red-700:#d32f2f;--md-red-800:#c62828;--md-red-900:#b71c1c;--md-red-a100:#ff8880;--md-red-a200:#ff5252;--md-red-a400:#ff1745;--md-red-a700:#d50000;--md-pink-50:#fce4ec;--md-pink-100:#f8bbd0;--md-pink-200:#f48fb2;--md-pink-300:#f06294;--md-pink-400:#ec407c;--md-pink-500:#e91e65;--md-pink-600:#d81b60;--md-pink-700:#c2185c;--md-pink-800:#ad1459;--md-pink-900:#880e4f;--md-pink-a100:#ff80ac;--md-pink-a200:#ff4083;--md-pink-a400:#f5005a;--md-pink-a700:#c51162;--md-purple-50:#f3e5f5;--md-purple-100:#e1bee7;--md-purple-200:#ce93d8;--md-purple-300:#ba68c8;--md-purple-400:#aa47bc;--md-purple-500:#9b27b0;--md-purple-600:#8d24aa;--md-purple-700:#7b1fa2;--md-purple-800:#691b9a;--md-purple-900:#4a148c;--md-purple-a100:#e980fc;--md-purple-a200:#df40fb;--md-purple-a400:#d400f9;--md-purple-a700:#a0f;--md-deep-purple-50:#ede7f6;--md-deep-purple-100:#d1c4e9;--md-deep-purple-200:#b39ddb;--md-deep-purple-300:#9475cd;--md-deep-purple-400:#7c57c2;--md-deep-purple-500:#663ab7;--md-deep-purple-600:#5c35b1;--md-deep-purple-700:#502da8;--md-deep-purple-800:#4327a0;--md-deep-purple-900:#311b92;--md-deep-purple-a100:#b288ff;--md-deep-purple-a200:#7a4dff;--md-deep-purple-a400:#621fff;--md-deep-purple-a700:#6100ea;--md-indigo-50:#e8eaf6;--md-indigo-100:#c5cae9;--md-indigo-200:#9fa9da;--md-indigo-300:#7987cb;--md-indigo-400:#5c6dc0;--md-indigo-500:#3f53b5;--md-indigo-600:#394aab;--md-indigo-700:#30419f;--md-indigo-800:#283693;--md-indigo-900:#1a247e;--md-indigo-a100:#8c9fff;--md-indigo-a200:#5370fe;--md-indigo-a400:#3d5dfe;--md-indigo-a700:#3052fe;--md-blue-50:#e3f2fd;--md-blue-100:#bbdefb;--md-blue-200:#90ccf9;--md-blue-300:#64b7f6;--md-blue-400:#42a7f5;--md-blue-500:#2198f3;--md-blue-600:#1e88e5;--md-blue-700:#1979d2;--md-blue-800:#1568c0;--md-blue-900:#0d48a1;--md-blue-a100:#82b2ff;--md-blue-a200:#448cff;--md-blue-a400:#297bff;--md-blue-a700:#2962ff;--md-light-blue-50:#e1f5fe;--md-light-blue-100:#b3e6fc;--md-light-blue-200:#81d6fa;--md-light-blue-300:#4fc5f7;--md-light-blue-400:#29b8f6;--md-light-blue-500:#03acf4;--md-light-blue-600:#039de5;--md-light-blue-700:#0289d1;--md-light-blue-800:#0278bd;--md-light-blue-900:#01589b;--md-light-blue-a100:#80d9ff;--md-light-blue-a200:#40c6ff;--md-light-blue-a400:#00b2ff;--md-light-blue-a700:#0094ea;--md-cyan-50:#e0f7fa;--md-cyan-100:#b2ecf2;--md-cyan-200:#80dfea;--md-cyan-300:#4dd2e1;--md-cyan-400:#26c8da;--md-cyan-500:#00bfd4;--md-cyan-600:#00aec1;--md-cyan-700:#0099a7;--md-cyan-800:#00838f;--md-cyan-900:#006164;--md-cyan-a100:#84ffff;--md-cyan-a200:#18ff ...

# %%
karate = load(open('./karate.json', 'r'))
nova.visualize(karate, width=400, height=420, node_strength=-5)
# Out:
#         <iframe
#             srcdoc="&lt;!doctype html&gt;&lt;html lang=&quot;en&quot;&gt;&lt;head&gt;&lt;meta charset=&quot;utf-8&quot;/&gt;&lt;link rel=&quot;icon&quot; href=&quot;/favicon.ico&quot;/&gt;&lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,initial-scale=1&quot;/&gt;&lt;meta name=&quot;theme-color&quot; content=&quot;#000000&quot;/&gt;&lt;meta name=&quot;description&quot; content=&quot;Web site created using create-react-app&quot;/&gt;&lt;link rel=&quot;apple-touch-icon&quot; href=&quot;/logo192.png&quot;/&gt;&lt;link rel=&quot;manifest&quot; href=&quot;/manifest.json&quot;/&gt;&lt;title&gt;React App&lt;/title&gt;&lt;style&gt;html{font-size:16px;-moz-osx-font-smoothing:grayscale;-webkit-font-smoothing:antialiased;text-rendering:optimizeLegibility;-webkit-text-size-adjust:100%;-moz-text-size-adjust:100%;scroll-behavior:smooth}body,html{position:relative;width:100%;height:100%}body{margin:0;padding:0;box-sizing:border-box;font-family:-apple-system,BlinkMacSystemFont,&quot;Segoe UI&quot;,Roboto,Oxygen-Sans,Ubuntu,Cantarell,&quot;Helvetica Neue&quot;,sans-serif;color:#4a4a4a;font-size:1em;font-weight:400;line-height:1.5}*,:after,:before{box-sizing:inherit}a{color:#0064c8;text-decoration:none}a:hover{text-decoration:underline}a:visited{color:#0050a0}:root{--ease-cubic-in-out:cubic-bezier(0.645,0.045,0.355,1);--md-red-50:#ffebee;--md-red-100:#ffcdd2;--md-red-200:#ef9a9a;--md-red-300:#e57373;--md-red-400:#ef5350;--md-red-500:#f44336;--md-red-600:#e53835;--md-red-700:#d32f2f;--md-red-800:#c62828;--md-red-900:#b71c1c;--md-red-a100:#ff8880;--md-red-a200:#ff5252;--md-red-a400:#ff1745;--md-red-a700:#d50000;--md-pink-50:#fce4ec;--md-pink-100:#f8bbd0;--md-pink-200:#f48fb2;--md-pink-300:#f06294;--md-pink-400:#ec407c;--md-pink-500:#e91e65;--md-pink-600:#d81b60;--md-pink-700:#c2185c;--md-pink-800:#ad1459;--md-pink-900:#880e4f;--md-pink-a100:#ff80ac;--md-pink-a200:#ff4083;--md-pink-a400:#f5005a;--md-pink-a700:#c51162;--md-purple-50:#f3e5f5;--md-purple-100:#e1bee7;--md-purple-200:#ce93d8;--md-purple-300:#ba68c8;--md-purple-400:#aa47bc;--md-purple-500:#9b27b0;--md-purple-600:#8d24aa;--md-purple-700:#7b1fa2;--md-purple-800:#691b9a;--md-purple-900:#4a148c;--md-purple-a100:#e980fc;--md-purple-a200:#df40fb;--md-purple-a400:#d400f9;--md-purple-a700:#a0f;--md-deep-purple-50:#ede7f6;--md-deep-purple-100:#d1c4e9;--md-deep-purple-200:#b39ddb;--md-deep-purple-300:#9475cd;--md-deep-purple-400:#7c57c2;--md-deep-purple-500:#663ab7;--md-deep-purple-600:#5c35b1;--md-deep-purple-700:#502da8;--md-deep-purple-800:#4327a0;--md-deep-purple-900:#311b92;--md-deep-purple-a100:#b288ff;--md-deep-purple-a200:#7a4dff;--md-deep-purple-a400:#621fff;--md-deep-purple-a700:#6100ea;--md-indigo-50:#e8eaf6;--md-indigo-100:#c5cae9;--md-indigo-200:#9fa9da;--md-indigo-300:#7987cb;--md-indigo-400:#5c6dc0;--md-indigo-500:#3f53b5;--md-indigo-600:#394aab;--md-indigo-700:#30419f;--md-indigo-800:#283693;--md-indigo-900:#1a247e;--md-indigo-a100:#8c9fff;--md-indigo-a200:#5370fe;--md-indigo-a400:#3d5dfe;--md-indigo-a700:#3052fe;--md-blue-50:#e3f2fd;--md-blue-100:#bbdefb;--md-blue-200:#90ccf9;--md-blue-300:#64b7f6;--md-blue-400:#42a7f5;--md-blue-500:#2198f3;--md-blue-600:#1e88e5;--md-blue-700:#1979d2;--md-blue-800:#1568c0;--md-blue-900:#0d48a1;--md-blue-a100:#82b2ff;--md-blue-a200:#448cff;--md-blue-a400:#297bff;--md-blue-a700:#2962ff;--md-light-blue-50:#e1f5fe;--md-light-blue-100:#b3e6fc;--md-light-blue-200:#81d6fa;--md-light-blue-300:#4fc5f7;--md-light-blue-400:#29b8f6;--md-light-blue-500:#03acf4;--md-light-blue-600:#039de5;--md-light-blue-700:#0289d1;--md-light-blue-800:#0278bd;--md-light-blue-900:#01589b;--md-light-blue-a100:#80d9ff;--md-light-blue-a200:#40c6ff;--md-light-blue-a400:#00b2ff;--md-light-blue-a700:#0094ea;--md-cyan-50:#e0f7fa;--md-cyan-100:#b2ecf2;--md-cyan-200:#80dfea;--md-cyan-300:#4dd2e1;--md-cyan-400:#26c8da;--md-cyan-500:#00bfd4;--md-cyan-600:#00aec1;--md-cyan-700:#0099a7;--md-cyan-800:#00838f;--md-cyan-900:#006164;--md-cyan-a100:#84ffff;--md-cyan-a200:#18ff ...

# %% [markdown]
# ## 4. Multiple Instances
#
# Sometimes it is helpful to compare multiple instances of the same VA tool (e.g., with different data or configurations) side by side. If we are running this notebook in JupyterLab, Jupyter Lite, or Jupyter Notebook > 4.0, we can use [StickyLand](https://github.com/xiaohk/stickyland) to do that. We can even create a dashoboard to mix and match different VA tools!

# %% [markdown]
# <img src="https://i.imgur.com/XhYD2hl.png" width="1400px" />
