# %%
import novagraph as nova
from json import load

# %% [markdown]
# ## 1. Visual Analytics in Notebooks
#
# We can directly use `nova.visualize()` to visualize a graph (loaded from a JSON file) with default configurations.

# %%
# Read the data
miserables = load(open('./miserables.json', 'r'))

# Pass data to our VA tool and show it below the cell
nova.visualize(miserables)
# Out:
# <!doctype html><html lang="en"><head><meta charset="utf-8"/><link rel="icon" href="/favicon.ico"/><meta name="viewport" content="width=device-width,initial-scale=1"/><meta name="theme-color" content="#000000"/><meta name="description" content="Web site created using create-react-app"/><link rel="apple-touch-icon" href="/logo192.png"/><link rel="manifest" href="/manifest.json"/><title>React App</title><script defer="defer" src="/static/js/main.7095fa21.js"></script><link href="/static/css/main.c6bc7174.css" rel="stylesheet"></head><body><noscript>You need to enable JavaScript to run this app.</noscript><div id="root"></div></body></html>
#         <iframe
#             srcdoc="&lt;!doctype html&gt;&lt;html lang=&quot;en&quot;&gt;&lt;head&gt;&lt;meta charset=&quot;utf-8&quot;/&gt;&lt;link rel=&quot;icon&quot; href=&quot;/favicon.ico&quot;/&gt;&lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,initial-scale=1&quot;/&gt;&lt;meta name=&quot;theme-color&quot; content=&quot;#000000&quot;/&gt;&lt;meta name=&quot;description&quot; content=&quot;Web site created using create-react-app&quot;/&gt;&lt;link rel=&quot;apple-touch-icon&quot; href=&quot;/logo192.png&quot;/&gt;&lt;link rel=&quot;manifest&quot; href=&quot;/manifest.json&quot;/&gt;&lt;title&gt;React App&lt;/title&gt;&lt;script defer=&quot;defer&quot; src=&quot;/static/js/main.7095fa21.js&quot;&gt;&lt;/script&gt;&lt;link href=&quot;/static/css/main.c6bc7174.css&quot; rel=&quot;stylesheet&quot;&gt;&lt;/head&gt;&lt;body&gt;&lt;noscript&gt;You need to enable JavaScript to run this app.&lt;/noscript&gt;&lt;div id=&quot;root&quot;&gt;&lt;/div&gt;&lt;/body&gt;&lt;/html&gt;"
#             frameBorder="0"
#             width="100%"
#             height="520px"
#             id="nova-graph-iframe-69673366">
#         </iframe>

# %% [markdown]
# ## 2. Customized Visual Analytics
#
# We can also pass argumetns into `nova.visualize()` to create a customized VA tool. We can control the size of the graph view and initial force layout strengths.
#
# Run `?nova.visualize` to see all parameters.

# %%
# ?nova.visualize

# %%
nova.visualize(miserables, width=400, height=420, node_strength=-20)
# Out:
#         <iframe
#             srcdoc="&lt;!DOCTYPE html&gt;&lt;html lang=&quot;en&quot;&gt;&lt;head&gt;&lt;meta charset=&quot;UTF-8&quot; /&gt;&lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot; /&gt;&lt;title&gt;Nova Graph&lt;/title&gt;&lt;style&gt;$html {
#   font-size: 16px;
#   -moz-osx-font-smoothing: grayscale;
#   -webkit-font-smoothing: antialiased;
#   text-rendering: optimizeLegibility;
#   -webkit-text-size-adjust: 100%;
#   -moz-text-size-adjust: 100%;
#   scroll-behavior: smooth;
# }
#
# html,
# body {
#   position: relative;
#   width: 100%;
#   height: 100%;
# }
#
# body {
#   margin: 0px;
#   padding: 0px;
#   box-sizing: border-box;
#   font-family: -apple-system, BlinkMacSystemFont, &quot;Segoe UI&quot;, Roboto, Oxygen-Sans, Ubuntu, Cantarell, &quot;Helvetica Neue&quot;, sans-serif;
#   color: hsl(0, 0%, 29%);
#   font-size: 1em;
#   font-weight: 400;
#   line-height: 1.5;
# }
#
# *,
# ::after,
# ::before {
#   box-sizing: inherit;
# }
#
# a {
#   color: rgb(0, 100, 200);
#   text-decoration: none;
# }
#
# a:hover {
#   text-decoration: underline;
# }
#
# a:visited {
#   color: rgb(0, 80, 160);
# }
# :root {
#   --ease-cubic-in-out: cubic-bezier(0.645, 0.045, 0.355, 1);
#
#   --md-red-50: hsl(350, 100.0%, 96.08%);
#   --md-red-100: hsl(354, 100.0%, 90.2%);
#   --md-red-200: hsl(0, 72.65%, 77.06%);
#   --md-red-300: hsl(0, 68.67%, 67.45%);
#   --md-red-400: hsl(1, 83.25%, 62.55%);
#   --md-red-500: hsl(4, 89.62%, 58.43%);
#   --md-red-600: hsl(1, 77.19%, 55.29%);
#   --md-red-700: hsl(0, 65.08%, 50.59%);
#   --md-red-800: hsl(0, 66.39%, 46.67%);
#   --md-red-900: hsl(0, 73.46%, 41.37%);
#   --md-red-a100: hsl(4, 100.0%, 75.1%);
#   --md-red-a200: hsl(0, 100.0%, 66.08%);
#   --md-red-a400: hsl(348, 100.0%, 54.51%);
#   --md-red-a700: hsl(0, 100.0%, 41.76%);
#
#   --md-pink-50: hsl(340, 80.0%, 94.12%);
#   --md-pink-100: hsl(339, 81.33%, 85.29%);
#   --md-pink-200: hsl(339, 82.11%, 75.88%);
#   --md-pink-300: hsl(339, 82.56%, 66.27%);
#   --md-pink-400: hsl(339, 81.9%, 58.82%);
#   --md-pink-500: hsl(339, 82.19%, 51.57%);
#   --md-pink-600: hsl(338, 77.78%, 47.65%);
#   --md-pink-700: hsl(336, 77.98%, 42.75%);
#   --md-pink-800: hsl(333, 79.27%, 37.84%);
#   --md-pink-900: hsl(328, 81.33%, 29.41%);
#   --md-pink-a100: hsl(339, 100.0%, 75.1%);
#   --md-pink-a200: hsl(339, 100.0%, 62.55%);
#   --md-pink-a400: hsl(338, 100.0%, 48.04%);
#   --md-pink-a700: hsl(333, 84.11%, 41.96%);
#
#   --md-purple-50: hsl(292, 44.44%, 92.94%);
#   --md-purple-100: hsl(291, 46.07%, 82.55%);
#   --md-purple-200: hsl(291, 46.94%, 71.18%);
#   --md-purple-300: hsl(291, 46.6%, 59.61%);
#   --md-purple-400: hsl(291, 46.61%, 50.78%);
#   --md-purple-500: hsl(291, 63.72%, 42.16%);
#   --md-purple-600: hsl(287, 65.05%, 40.39%);
#   --md-purple-700: hsl(282, 67.88%, 37.84%);
#   --md-purple-800: hsl(277, 70.17%, 35.49%);
#   --md-purple-900: hsl(267, 75.0%, 31.37%);
#   --md-purple-a100: hsl(291, 95.38%, 74.51%);
#   --md-purple-a200: hsl(291, 95.9%, 61.76%);
#   --md-purple-a400: hsl(291, 100.0%, 48.82%);
#   --md-purple-a700: hsl(280, 100.0%, 50.0%);
#
#   --md-deep-purple-50: hsl(264, 45.45%, 93.53%);
#   --md-deep-purple-100: hsl(261, 45.68%, 84.12%);
#   --md-deep-purple-200: hsl(261, 46.27%, 73.73%);
#   --md-deep-purple-300: hsl(261, 46.81%, 63.14%);
#   --md-deep-purple-400: hsl(261, 46.72%, 55.1%);
#   --md-deep-purple-500: hsl(261, 51.87%, 47.25%);
#   --md-deep-purple-600: hsl(259, 53.91%, 45.1%);
#   --md-deep-purple-700: hsl(257, 57.75%, 41.76%);
#   --md-deep-purple-800: hsl(254, 60.8%, 39.02%);
#   --md-deep-purple-900: hsl(251, 68.79%, 33.92%);
#   --md-deep-purple-a100: hsl(261, 100.0%, 76.67%);
#   --md-deep-purple-a200: hsl(255, 100.0%, 65.1%);
#   --md-deep-purple-a400: hsl(258, 100.0%, 56.08%);
#   --md-deep-purple-a700: hsl(265, 100.0%, 45.88%);
#
#   --md-indigo-50: hsl(231, 43.75%, 93.73%);
#   --md-indigo-100: hsl(231, 45.0%, 84.31%);
#   --md-indigo-200: hsl(230, 44.36%, 73.92%);
#   --md-indigo-300: hsl(230, 44.09%, 63.53%);
#   --md-indigo-400: hsl(230, 44.25%, 55.69%);
#   --md-indigo-500: hsl(230, 48.36%, 47.84%);
#   --md-indigo-600: hsl(231, 50.0%, 44.71%);
#   --md-indigo-700: hsl(231, 53.62%, 40.59%);
#   --md-indigo-800: hsl(232, 57.22%, 36.67%);
#   --md-indigo-900: hsl(234, 65.79%, 29.8%);
#   --md-indigo-a100: hsl(230, 100.0%, 77.45%);
#   --md-indigo-a200: hsl(230, 98.84%, 66.08%);
#   --md-indigo-a400: hsl(230, 98.97%, 61.76%);
#   --md-indigo-a700: hsl(230, 99.04%, 59.22%);
#
#   --md-blue-50: hsl(205, 86.67%, 94.12%);
#   --md-blue-100: hsl(207, 88.89%, 85.88%);
#   --md-blue-200: hsl(206, 89.74%, 77.06%);
#   --md-blue-300: hsl(206, 89.02%, 67.84%);
#   --md-blue-400: hsl(206, 89.95%, 60.98%);
#   --md-blue-500: hsl(206, 89.74%, 54.12%);
#   --md-blue-600: hsl(208, 79.28%, 50.78%);
#   --md-blue-700: hsl(209, 78.72%, 46.08%);
#   --md-blue-800: hsl(211, 80.28%, 41.76%);
#   --md-blue-900: hsl(216, 85.06%, 34.12%);
#   --md-blue-a100: hsl(217, 100.0%, 75.49%);
#   --md-blue-a200: hsl(217, 100.0%, 63.33%);
#   --md-blue-a400: hsl(217, 100.0%, 58.04%);
#   --md-blue-a700: hsl(224, 100.0%, 58.04%);
#
#   --md-light-blue-50: hsl(198, 93.55%, 93.92%);
#   --md-light-blue-100: hsl(198, 92.41%, 84.51%);
#   --md-light-blue-200: hsl(198, 92.37%, 74.31%);
#   --md-light-blue-300: hsl(198, 91.3%, 63.92%);
#   --md-light-blue-400: hsl(198, 91.93%, 56.27%);
#   --md-light-blue-500: hsl(198, 97.57%, 48.43%);
#   --md-light-blue-600: hsl(199, 97.41%, 45.49%);
#   --md-light-blue-700: hsl(201, 98.1%, 41.37%);
#   --md-light-blue-800: hsl(202, 97.91%, 37.45%);
#   --md-light-blue-900: hsl(206, 98.72%, 30.59%);
#   --md-light-blue-a100: hsl(198, 100.0%, 75.1%);
#   --md-light-blue-a200: hsl(198, 100.0%, 62.55%);
#   --md-light-blue-a400: hsl(198, 100.0%, 50.0%);
#   --md-light-blue-a700: hsl(202, 100.0%, 45.88%);
#
#   --md-cyan-50: hsl(186, 72.22%, 92.94%);
#   --md-cyan-100: hsl(186, 71.11%, 82.35%);
#   --md-cyan-200: hsl(186, 71.62%, 70.98%);
#   --md-cyan-300: hsl(186, 71.15%, 59.22%);
#   --md-cyan-400: hsl(186, 70.87%, 50.2%);
#   --md-cyan-500: hsl(186, 100.0%, 41.57%);
#   --md-cyan-600: hsl(186, 100.0%, 37.84%);
#   --md-cyan-700: hsl(185, 100.0%, 32.75%);
#   --md-cyan-800: hsl(185, 100.0%, 28.04%);
#   --md-cyan-900: hsl(182, 100.0%, 19.61%);
#   --md-cyan-a100: hsl(180, 100.0%, 75.88%);
#   --md-cyan-a200: hsl(180, 100.0%, 54.71%);
#   --md-cyan-a400: hsl(186, 100.0%, 50.0%);
#   --md-cyan-a700: hsl(187, 100.0%, 41.57%);
#
#   --md-teal-50: hsl(176, 40.91%, 91.37%);
#   --md-teal-100: hsl(174, 41.28%, 78.63%);
#   --md-teal-200: hsl(174, 41.9%, 64.9%);
#   --md-teal-300: hsl(174, 41.83%, 50.78%);
#   --md-teal-400: hsl(174, 62.75%, 40.0%);
#   --md-teal-500: hsl(174, 100.0%, 29.41%);
#   --md-teal-600: hsl(173, 100.0%, 26.86%);
#   --md-teal-700: hsl(173, 100.0%, 23.73%);
#   --md-teal-800: hsl(172, 100.0%, 20.59%);
#   --md-teal-900: hsl(169, 100.0%, 15.1%);
#   --md-teal-a100: hsl(166, 100.0%, 82.75%);
#   --md-teal-a200: hsl(165, 100.0%, 69.61%);
#   --md-teal-a400: hsl(165, 82.26%, 51.37%);
#   --md-teal-a700: hsl(171, 100.0%, 37.45%);
#
#   --md-green-50: hsl(124, 39.39%, 93.53%);
#   --md-green-100: hsl(121, 37.5%, 84.31%);
#   --md-green-200: hsl(122, 37.4%, 74.31%);
#   --md-green-300: hsl(122, 38.46%, 64.31%);
#   --md-green-400: hsl(122, 38.46%, 56.67%);
#   --md-green-500: hsl(122, 39.44%, 49.22%);
#   --md-green-600: hsl(122, 40.97%, 44.51%);
#   --md-green-700: hsl(122, 43.43%, 38.82%);
#   --md-green-800: hsl(123, 46.2%, 33.53%);
#   --md-green-900: hsl(124, 55.37%, 23.73%);
#   --md-green-a100: hsl(136, 77.22%, 84.51%);
#   --md-green-a200: hsl(150, 81.82%, 67.65%);
#   --md-green-a400: hsl(150, 100.0%, 45.1%);
#   --md-green-a700: hsl(144, 100.0%, 39.22%);
#
#   --md-light-green-50: hsl(88, 51.72%, 94.31%);
#   --md-light-green-100: hsl(87, 50.68%, 85.69%);
#   --md-light-green-200: hsl(88, 50.0%, 76.47%);
#   --md-light-green-300: hsl(87, 50.0%, 67.06%);
#   --md-light-green-400: hsl(87, 50.24%, 59.8%);
#   --md-light-green-500: hsl(87, 50.21%, 52.75%);
#   --md-light-green-600: hsl(89, 46.12%, 48.04%);
#   --md-light-green-700: hsl(92, 47.91%, 42.16%);
#   --md-light-green-800: hsl(95, 49.46%, 36.47%);
#   --md-light-green-900: hsl(103, 55.56%, 26.47%);
#   --md-light-green-a100: hsl(87, 100.0%, 78.24%);
#   --md-light-green-a200: hsl(87, 100.0%, 67.45%);
#   --md-

# %%
nova.visualize(miserables, width=800, height=820, node_strength=-90)
# Out:
#         <iframe
#             srcdoc="&lt;!DOCTYPE html&gt;&lt;html lang=&quot;en&quot;&gt;&lt;head&gt;&lt;meta charset=&quot;UTF-8&quot; /&gt;&lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot; /&gt;&lt;title&gt;Nova Graph&lt;/title&gt;&lt;style&gt;$html {
#   font-size: 16px;
#   -moz-osx-font-smoothing: grayscale;
#   -webkit-font-smoothing: antialiased;
#   text-rendering: optimizeLegibility;
#   -webkit-text-size-adjust: 100%;
#   -moz-text-size-adjust: 100%;
#   scroll-behavior: smooth;
# }
#
# html,
# body {
#   position: relative;
#   width: 100%;
#   height: 100%;
# }
#
# body {
#   margin: 0px;
#   padding: 0px;
#   box-sizing: border-box;
#   font-family: -apple-system, BlinkMacSystemFont, &quot;Segoe UI&quot;, Roboto, Oxygen-Sans, Ubuntu, Cantarell, &quot;Helvetica Neue&quot;, sans-serif;
#   color: hsl(0, 0%, 29%);
#   font-size: 1em;
#   font-weight: 400;
#   line-height: 1.5;
# }
#
# *,
# ::after,
# ::before {
#   box-sizing: inherit;
# }
#
# a {
#   color: rgb(0, 100, 200);
#   text-decoration: none;
# }
#
# a:hover {
#   text-decoration: underline;
# }
#
# a:visited {
#   color: rgb(0, 80, 160);
# }
# :root {
#   --ease-cubic-in-out: cubic-bezier(0.645, 0.045, 0.355, 1);
#
#   --md-red-50: hsl(350, 100.0%, 96.08%);
#   --md-red-100: hsl(354, 100.0%, 90.2%);
#   --md-red-200: hsl(0, 72.65%, 77.06%);
#   --md-red-300: hsl(0, 68.67%, 67.45%);
#   --md-red-400: hsl(1, 83.25%, 62.55%);
#   --md-red-500: hsl(4, 89.62%, 58.43%);
#   --md-red-600: hsl(1, 77.19%, 55.29%);
#   --md-red-700: hsl(0, 65.08%, 50.59%);
#   --md-red-800: hsl(0, 66.39%, 46.67%);
#   --md-red-900: hsl(0, 73.46%, 41.37%);
#   --md-red-a100: hsl(4, 100.0%, 75.1%);
#   --md-red-a200: hsl(0, 100.0%, 66.08%);
#   --md-red-a400: hsl(348, 100.0%, 54.51%);
#   --md-red-a700: hsl(0, 100.0%, 41.76%);
#
#   --md-pink-50: hsl(340, 80.0%, 94.12%);
#   --md-pink-100: hsl(339, 81.33%, 85.29%);
#   --md-pink-200: hsl(339, 82.11%, 75.88%);
#   --md-pink-300: hsl(339, 82.56%, 66.27%);
#   --md-pink-400: hsl(339, 81.9%, 58.82%);
#   --md-pink-500: hsl(339, 82.19%, 51.57%);
#   --md-pink-600: hsl(338, 77.78%, 47.65%);
#   --md-pink-700: hsl(336, 77.98%, 42.75%);
#   --md-pink-800: hsl(333, 79.27%, 37.84%);
#   --md-pink-900: hsl(328, 81.33%, 29.41%);
#   --md-pink-a100: hsl(339, 100.0%, 75.1%);
#   --md-pink-a200: hsl(339, 100.0%, 62.55%);
#   --md-pink-a400: hsl(338, 100.0%, 48.04%);
#   --md-pink-a700: hsl(333, 84.11%, 41.96%);
#
#   --md-purple-50: hsl(292, 44.44%, 92.94%);
#   --md-purple-100: hsl(291, 46.07%, 82.55%);
#   --md-purple-200: hsl(291, 46.94%, 71.18%);
#   --md-purple-300: hsl(291, 46.6%, 59.61%);
#   --md-purple-400: hsl(291, 46.61%, 50.78%);
#   --md-purple-500: hsl(291, 63.72%, 42.16%);
#   --md-purple-600: hsl(287, 65.05%, 40.39%);
#   --md-purple-700: hsl(282, 67.88%, 37.84%);
#   --md-purple-800: hsl(277, 70.17%, 35.49%);
#   --md-purple-900: hsl(267, 75.0%, 31.37%);
#   --md-purple-a100: hsl(291, 95.38%, 74.51%);
#   --md-purple-a200: hsl(291, 95.9%, 61.76%);
#   --md-purple-a400: hsl(291, 100.0%, 48.82%);
#   --md-purple-a700: hsl(280, 100.0%, 50.0%);
#
#   --md-deep-purple-50: hsl(264, 45.45%, 93.53%);
#   --md-deep-purple-100: hsl(261, 45.68%, 84.12%);
#   --md-deep-purple-200: hsl(261, 46.27%, 73.73%);
#   --md-deep-purple-300: hsl(261, 46.81%, 63.14%);
#   --md-deep-purple-400: hsl(261, 46.72%, 55.1%);
#   --md-deep-purple-500: hsl(261, 51.87%, 47.25%);
#   --md-deep-purple-600: hsl(259, 53.91%, 45.1%);
#   --md-deep-purple-700: hsl(257, 57.75%, 41.76%);
#   --md-deep-purple-800: hsl(254, 60.8%, 39.02%);
#   --md-deep-purple-900: hsl(251, 68.79%, 33.92%);
#   --md-deep-purple-a100: hsl(261, 100.0%, 76.67%);
#   --md-deep-purple-a200: hsl(255, 100.0%, 65.1%);
#   --md-deep-purple-a400: hsl(258, 100.0%, 56.08%);
#   --md-deep-purple-a700: hsl(265, 100.0%, 45.88%);
#
#   --md-indigo-50: hsl(231, 43.75%, 93.73%);
#   --md-indigo-100: hsl(231, 45.0%, 84.31%);
#   --md-indigo-200: hsl(230, 44.36%, 73.92%);
#   --md-indigo-300: hsl(230, 44.09%, 63.53%);
#   --md-indigo-400: hsl(230, 44.25%, 55.69%);
#   --md-indigo-500: hsl(230, 48.36%, 47.84%);
#   --md-indigo-600: hsl(231, 50.0%, 44.71%);
#   --md-indigo-700: hsl(231, 53.62%, 40.59%);
#   --md-indigo-800: hsl(232, 57.22%, 36.67%);
#   --md-indigo-900: hsl(234, 65.79%, 29.8%);
#   --md-indigo-a100: hsl(230, 100.0%, 77.45%);
#   --md-indigo-a200: hsl(230, 98.84%, 66.08%);
#   --md-indigo-a400: hsl(230, 98.97%, 61.76%);
#   --md-indigo-a700: hsl(230, 99.04%, 59.22%);
#
#   --md-blue-50: hsl(205, 86.67%, 94.12%);
#   --md-blue-100: hsl(207, 88.89%, 85.88%);
#   --md-blue-200: hsl(206, 89.74%, 77.06%);
#   --md-blue-300: hsl(206, 89.02%, 67.84%);
#   --md-blue-400: hsl(206, 89.95%, 60.98%);
#   --md-blue-500: hsl(206, 89.74%, 54.12%);
#   --md-blue-600: hsl(208, 79.28%, 50.78%);
#   --md-blue-700: hsl(209, 78.72%, 46.08%);
#   --md-blue-800: hsl(211, 80.28%, 41.76%);
#   --md-blue-900: hsl(216, 85.06%, 34.12%);
#   --md-blue-a100: hsl(217, 100.0%, 75.49%);
#   --md-blue-a200: hsl(217, 100.0%, 63.33%);
#   --md-blue-a400: hsl(217, 100.0%, 58.04%);
#   --md-blue-a700: hsl(224, 100.0%, 58.04%);
#
#   --md-light-blue-50: hsl(198, 93.55%, 93.92%);
#   --md-light-blue-100: hsl(198, 92.41%, 84.51%);
#   --md-light-blue-200: hsl(198, 92.37%, 74.31%);
#   --md-light-blue-300: hsl(198, 91.3%, 63.92%);
#   --md-light-blue-400: hsl(198, 91.93%, 56.27%);
#   --md-light-blue-500: hsl(198, 97.57%, 48.43%);
#   --md-light-blue-600: hsl(199, 97.41%, 45.49%);
#   --md-light-blue-700: hsl(201, 98.1%, 41.37%);
#   --md-light-blue-800: hsl(202, 97.91%, 37.45%);
#   --md-light-blue-900: hsl(206, 98.72%, 30.59%);
#   --md-light-blue-a100: hsl(198, 100.0%, 75.1%);
#   --md-light-blue-a200: hsl(198, 100.0%, 62.55%);
#   --md-light-blue-a400: hsl(198, 100.0%, 50.0%);
#   --md-light-blue-a700: hsl(202, 100.0%, 45.88%);
#
#   --md-cyan-50: hsl(186, 72.22%, 92.94%);
#   --md-cyan-100: hsl(186, 71.11%, 82.35%);
#   --md-cyan-200: hsl(186, 71.62%, 70.98%);
#   --md-cyan-300: hsl(186, 71.15%, 59.22%);
#   --md-cyan-400: hsl(186, 70.87%, 50.2%);
#   --md-cyan-500: hsl(186, 100.0%, 41.57%);
#   --md-cyan-600: hsl(186, 100.0%, 37.84%);
#   --md-cyan-700: hsl(185, 100.0%, 32.75%);
#   --md-cyan-800: hsl(185, 100.0%, 28.04%);
#   --md-cyan-900: hsl(182, 100.0%, 19.61%);
#   --md-cyan-a100: hsl(180, 100.0%, 75.88%);
#   --md-cyan-a200: hsl(180, 100.0%, 54.71%);
#   --md-cyan-a400: hsl(186, 100.0%, 50.0%);
#   --md-cyan-a700: hsl(187, 100.0%, 41.57%);
#
#   --md-teal-50: hsl(176, 40.91%, 91.37%);
#   --md-teal-100: hsl(174, 41.28%, 78.63%);
#   --md-teal-200: hsl(174, 41.9%, 64.9%);
#   --md-teal-300: hsl(174, 41.83%, 50.78%);
#   --md-teal-400: hsl(174, 62.75%, 40.0%);
#   --md-teal-500: hsl(174, 100.0%, 29.41%);
#   --md-teal-600: hsl(173, 100.0%, 26.86%);
#   --md-teal-700: hsl(173, 100.0%, 23.73%);
#   --md-teal-800: hsl(172, 100.0%, 20.59%);
#   --md-teal-900: hsl(169, 100.0%, 15.1%);
#   --md-teal-a100: hsl(166, 100.0%, 82.75%);
#   --md-teal-a200: hsl(165, 100.0%, 69.61%);
#   --md-teal-a400: hsl(165, 82.26%, 51.37%);
#   --md-teal-a700: hsl(171, 100.0%, 37.45%);
#
#   --md-green-50: hsl(124, 39.39%, 93.53%);
#   --md-green-100: hsl(121, 37.5%, 84.31%);
#   --md-green-200: hsl(122, 37.4%, 74.31%);
#   --md-green-300: hsl(122, 38.46%, 64.31%);
#   --md-green-400: hsl(122, 38.46%, 56.67%);
#   --md-green-500: hsl(122, 39.44%, 49.22%);
#   --md-green-600: hsl(122, 40.97%, 44.51%);
#   --md-green-700: hsl(122, 43.43%, 38.82%);
#   --md-green-800: hsl(123, 46.2%, 33.53%);
#   --md-green-900: hsl(124, 55.37%, 23.73%);
#   --md-green-a100: hsl(136, 77.22%, 84.51%);
#   --md-green-a200: hsl(150, 81.82%, 67.65%);
#   --md-green-a400: hsl(150, 100.0%, 45.1%);
#   --md-green-a700: hsl(144, 100.0%, 39.22%);
#
#   --md-light-green-50: hsl(88, 51.72%, 94.31%);
#   --md-light-green-100: hsl(87, 50.68%, 85.69%);
#   --md-light-green-200: hsl(88, 50.0%, 76.47%);
#   --md-light-green-300: hsl(87, 50.0%, 67.06%);
#   --md-light-green-400: hsl(87, 50.24%, 59.8%);
#   --md-light-green-500: hsl(87, 50.21%, 52.75%);
#   --md-light-green-600: hsl(89, 46.12%, 48.04%);
#   --md-light-green-700: hsl(92, 47.91%, 42.16%);
#   --md-light-green-800: hsl(95, 49.46%, 36.47%);
#   --md-light-green-900: hsl(103, 55.56%, 26.47%);
#   --md-light-green-a100: hsl(87, 100.0%, 78.24%);
#   --md-light-green-a200: hsl(87, 100.0%, 67.45%);
#   --md-

# %% [markdown]
# ## 3. Different Datasets
#
# We can pass different datasets into this simple VA tool through the first argument of `nova.visualize()`.

# %%
stackoverflow = load(open('./stackoverflow.json', 'r'))
nova.visualize(
    stackoverflow,
    width=400,
    height=420,
    node_strength=-10,
    link_strength=4
)
# Out:
#         <iframe
#             srcdoc="&lt;!DOCTYPE html&gt;&lt;html lang=&quot;en&quot;&gt;&lt;head&gt;&lt;meta charset=&quot;UTF-8&quot; /&gt;&lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot; /&gt;&lt;title&gt;Nova Graph&lt;/title&gt;&lt;style&gt;$html {
#   font-size: 16px;
#   -moz-osx-font-smoothing: grayscale;
#   -webkit-font-smoothing: antialiased;
#   text-rendering: optimizeLegibility;
#   -webkit-text-size-adjust: 100%;
#   -moz-text-size-adjust: 100%;
#   scroll-behavior: smooth;
# }
#
# html,
# body {
#   position: relative;
#   width: 100%;
#   height: 100%;
# }
#
# body {
#   margin: 0px;
#   padding: 0px;
#   box-sizing: border-box;
#   font-family: -apple-system, BlinkMacSystemFont, &quot;Segoe UI&quot;, Roboto, Oxygen-Sans, Ubuntu, Cantarell, &quot;Helvetica Neue&quot;, sans-serif;
#   color: hsl(0, 0%, 29%);
#   font-size: 1em;
#   font-weight: 400;
#   line-height: 1.5;
# }
#
# *,
# ::after,
# ::before {
#   box-sizing: inherit;
# }
#
# a {
#   color: rgb(0, 100, 200);
#   text-decoration: none;
# }
#
# a:hover {
#   text-decoration: underline;
# }
#
# a:visited {
#   color: rgb(0, 80, 160);
# }
# :root {
#   --ease-cubic-in-out: cubic-bezier(0.645, 0.045, 0.355, 1);
#
#   --md-red-50: hsl(350, 100.0%, 96.08%);
#   --md-red-100: hsl(354, 100.0%, 90.2%);
#   --md-red-200: hsl(0, 72.65%, 77.06%);
#   --md-red-300: hsl(0, 68.67%, 67.45%);
#   --md-red-400: hsl(1, 83.25%, 62.55%);
#   --md-red-500: hsl(4, 89.62%, 58.43%);
#   --md-red-600: hsl(1, 77.19%, 55.29%);
#   --md-red-700: hsl(0, 65.08%, 50.59%);
#   --md-red-800: hsl(0, 66.39%, 46.67%);
#   --md-red-900: hsl(0, 73.46%, 41.37%);
#   --md-red-a100: hsl(4, 100.0%, 75.1%);
#   --md-red-a200: hsl(0, 100.0%, 66.08%);
#   --md-red-a400: hsl(348, 100.0%, 54.51%);
#   --md-red-a700: hsl(0, 100.0%, 41.76%);
#
#   --md-pink-50: hsl(340, 80.0%, 94.12%);
#   --md-pink-100: hsl(339, 81.33%, 85.29%);
#   --md-pink-200: hsl(339, 82.11%, 75.88%);
#   --md-pink-300: hsl(339, 82.56%, 66.27%);
#   --md-pink-400: hsl(339, 81.9%, 58.82%);
#   --md-pink-500: hsl(339, 82.19%, 51.57%);
#   --md-pink-600: hsl(338, 77.78%, 47.65%);
#   --md-pink-700: hsl(336, 77.98%, 42.75%);
#   --md-pink-800: hsl(333, 79.27%, 37.84%);
#   --md-pink-900: hsl(328, 81.33%, 29.41%);
#   --md-pink-a100: hsl(339, 100.0%, 75.1%);
#   --md-pink-a200: hsl(339, 100.0%, 62.55%);
#   --md-pink-a400: hsl(338, 100.0%, 48.04%);
#   --md-pink-a700: hsl(333, 84.11%, 41.96%);
#
#   --md-purple-50: hsl(292, 44.44%, 92.94%);
#   --md-purple-100: hsl(291, 46.07%, 82.55%);
#   --md-purple-200: hsl(291, 46.94%, 71.18%);
#   --md-purple-300: hsl(291, 46.6%, 59.61%);
#   --md-purple-400: hsl(291, 46.61%, 50.78%);
#   --md-purple-500: hsl(291, 63.72%, 42.16%);
#   --md-purple-600: hsl(287, 65.05%, 40.39%);
#   --md-purple-700: hsl(282, 67.88%, 37.84%);
#   --md-purple-800: hsl(277, 70.17%, 35.49%);
#   --md-purple-900: hsl(267, 75.0%, 31.37%);
#   --md-purple-a100: hsl(291, 95.38%, 74.51%);
#   --md-purple-a200: hsl(291, 95.9%, 61.76%);
#   --md-purple-a400: hsl(291, 100.0%, 48.82%);
#   --md-purple-a700: hsl(280, 100.0%, 50.0%);
#
#   --md-deep-purple-50: hsl(264, 45.45%, 93.53%);
#   --md-deep-purple-100: hsl(261, 45.68%, 84.12%);
#   --md-deep-purple-200: hsl(261, 46.27%, 73.73%);
#   --md-deep-purple-300: hsl(261, 46.81%, 63.14%);
#   --md-deep-purple-400: hsl(261, 46.72%, 55.1%);
#   --md-deep-purple-500: hsl(261, 51.87%, 47.25%);
#   --md-deep-purple-600: hsl(259, 53.91%, 45.1%);
#   --md-deep-purple-700: hsl(257, 57.75%, 41.76%);
#   --md-deep-purple-800: hsl(254, 60.8%, 39.02%);
#   --md-deep-purple-900: hsl(251, 68.79%, 33.92%);
#   --md-deep-purple-a100: hsl(261, 100.0%, 76.67%);
#   --md-deep-purple-a200: hsl(255, 100.0%, 65.1%);
#   --md-deep-purple-a400: hsl(258, 100.0%, 56.08%);
#   --md-deep-purple-a700: hsl(265, 100.0%, 45.88%);
#
#   --md-indigo-50: hsl(231, 43.75%, 93.73%);
#   --md-indigo-100: hsl(231, 45.0%, 84.31%);
#   --md-indigo-200: hsl(230, 44.36%, 73.92%);
#   --md-indigo-300: hsl(230, 44.09%, 63.53%);
#   --md-indigo-400: hsl(230, 44.25%, 55.69%);
#   --md-indigo-500: hsl(230, 48.36%, 47.84%);
#   --md-indigo-600: hsl(231, 50.0%, 44.71%);
#   --md-indigo-700: hsl(231, 53.62%, 40.59%);
#   --md-indigo-800: hsl(232, 57.22%, 36.67%);
#   --md-indigo-900: hsl(234, 65.79%, 29.8%);
#   --md-indigo-a100: hsl(230, 100.0%, 77.45%);
#   --md-indigo-a200: hsl(230, 98.84%, 66.08%);
#   --md-indigo-a400: hsl(230, 98.97%, 61.76%);
#   --md-indigo-a700: hsl(230, 99.04%, 59.22%);
#
#   --md-blue-50: hsl(205, 86.67%, 94.12%);
#   --md-blue-100: hsl(207, 88.89%, 85.88%);
#   --md-blue-200: hsl(206, 89.74%, 77.06%);
#   --md-blue-300: hsl(206, 89.02%, 67.84%);
#   --md-blue-400: hsl(206, 89.95%, 60.98%);
#   --md-blue-500: hsl(206, 89.74%, 54.12%);
#   --md-blue-600: hsl(208, 79.28%, 50.78%);
#   --md-blue-700: hsl(209, 78.72%, 46.08%);
#   --md-blue-800: hsl(211, 80.28%, 41.76%);
#   --md-blue-900: hsl(216, 85.06%, 34.12%);
#   --md-blue-a100: hsl(217, 100.0%, 75.49%);
#   --md-blue-a200: hsl(217, 100.0%, 63.33%);
#   --md-blue-a400: hsl(217, 100.0%, 58.04%);
#   --md-blue-a700: hsl(224, 100.0%, 58.04%);
#
#   --md-light-blue-50: hsl(198, 93.55%, 93.92%);
#   --md-light-blue-100: hsl(198, 92.41%, 84.51%);
#   --md-light-blue-200: hsl(198, 92.37%, 74.31%);
#   --md-light-blue-300: hsl(198, 91.3%, 63.92%);
#   --md-light-blue-400: hsl(198, 91.93%, 56.27%);
#   --md-light-blue-500: hsl(198, 97.57%, 48.43%);
#   --md-light-blue-600: hsl(199, 97.41%, 45.49%);
#   --md-light-blue-700: hsl(201, 98.1%, 41.37%);
#   --md-light-blue-800: hsl(202, 97.91%, 37.45%);
#   --md-light-blue-900: hsl(206, 98.72%, 30.59%);
#   --md-light-blue-a100: hsl(198, 100.0%, 75.1%);
#   --md-light-blue-a200: hsl(198, 100.0%, 62.55%);
#   --md-light-blue-a400: hsl(198, 100.0%, 50.0%);
#   --md-light-blue-a700: hsl(202, 100.0%, 45.88%);
#
#   --md-cyan-50: hsl(186, 72.22%, 92.94%);
#   --md-cyan-100: hsl(186, 71.11%, 82.35%);
#   --md-cyan-200: hsl(186, 71.62%, 70.98%);
#   --md-cyan-300: hsl(186, 71.15%, 59.22%);
#   --md-cyan-400: hsl(186, 70.87%, 50.2%);
#   --md-cyan-500: hsl(186, 100.0%, 41.57%);
#   --md-cyan-600: hsl(186, 100.0%, 37.84%);
#   --md-cyan-700: hsl(185, 100.0%, 32.75%);
#   --md-cyan-800: hsl(185, 100.0%, 28.04%);
#   --md-cyan-900: hsl(182, 100.0%, 19.61%);
#   --md-cyan-a100: hsl(180, 100.0%, 75.88%);
#   --md-cyan-a200: hsl(180, 100.0%, 54.71%);
#   --md-cyan-a400: hsl(186, 100.0%, 50.0%);
#   --md-cyan-a700: hsl(187, 100.0%, 41.57%);
#
#   --md-teal-50: hsl(176, 40.91%, 91.37%);
#   --md-teal-100: hsl(174, 41.28%, 78.63%);
#   --md-teal-200: hsl(174, 41.9%, 64.9%);
#   --md-teal-300: hsl(174, 41.83%, 50.78%);
#   --md-teal-400: hsl(174, 62.75%, 40.0%);
#   --md-teal-500: hsl(174, 100.0%, 29.41%);
#   --md-teal-600: hsl(173, 100.0%, 26.86%);
#   --md-teal-700: hsl(173, 100.0%, 23.73%);
#   --md-teal-800: hsl(172, 100.0%, 20.59%);
#   --md-teal-900: hsl(169, 100.0%, 15.1%);
#   --md-teal-a100: hsl(166, 100.0%, 82.75%);
#   --md-teal-a200: hsl(165, 100.0%, 69.61%);
#   --md-teal-a400: hsl(165, 82.26%, 51.37%);
#   --md-teal-a700: hsl(171, 100.0%, 37.45%);
#
#   --md-green-50: hsl(124, 39.39%, 93.53%);
#   --md-green-100: hsl(121, 37.5%, 84.31%);
#   --md-green-200: hsl(122, 37.4%, 74.31%);
#   --md-green-300: hsl(122, 38.46%, 64.31%);
#   --md-green-400: hsl(122, 38.46%, 56.67%);
#   --md-green-500: hsl(122, 39.44%, 49.22%);
#   --md-green-600: hsl(122, 40.97%, 44.51%);
#   --md-green-700: hsl(122, 43.43%, 38.82%);
#   --md-green-800: hsl(123, 46.2%, 33.53%);
#   --md-green-900: hsl(124, 55.37%, 23.73%);
#   --md-green-a100: hsl(136, 77.22%, 84.51%);
#   --md-green-a200: hsl(150, 81.82%, 67.65%);
#   --md-green-a400: hsl(150, 100.0%, 45.1%);
#   --md-green-a700: hsl(144, 100.0%, 39.22%);
#
#   --md-light-green-50: hsl(88, 51.72%, 94.31%);
#   --md-light-green-100: hsl(87, 50.68%, 85.69%);
#   --md-light-green-200: hsl(88, 50.0%, 76.47%);
#   --md-light-green-300: hsl(87, 50.0%, 67.06%);
#   --md-light-green-400: hsl(87, 50.24%, 59.8%);
#   --md-light-green-500: hsl(87, 50.21%, 52.75%);
#   --md-light-green-600: hsl(89, 46.12%, 48.04%);
#   --md-light-green-700: hsl(92, 47.91%, 42.16%);
#   --md-light-green-800: hsl(95, 49.46%, 36.47%);
#   --md-light-green-900: hsl(103, 55.56%, 26.47%);
#   --md-light-green-a100: hsl(87, 100.0%, 78.24%);
#   --md-light-green-a200: hsl(87, 100.0%, 67.45%);
#   --md-

# %%
karate = load(open('./karate.json', 'r'))
nova.visualize(karate, width=400, height=420, node_strength=-5)
# Out:
#         <iframe
#             srcdoc="&lt;!DOCTYPE html&gt;&lt;html lang=&quot;en&quot;&gt;&lt;head&gt;&lt;meta charset=&quot;UTF-8&quot; /&gt;&lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot; /&gt;&lt;title&gt;Nova Graph&lt;/title&gt;&lt;style&gt;$html {
#   font-size: 16px;
#   -moz-osx-font-smoothing: grayscale;
#   -webkit-font-smoothing: antialiased;
#   text-rendering: optimizeLegibility;
#   -webkit-text-size-adjust: 100%;
#   -moz-text-size-adjust: 100%;
#   scroll-behavior: smooth;
# }
#
# html,
# body {
#   position: relative;
#   width: 100%;
#   height: 100%;
# }
#
# body {
#   margin: 0px;
#   padding: 0px;
#   box-sizing: border-box;
#   font-family: -apple-system, BlinkMacSystemFont, &quot;Segoe UI&quot;, Roboto, Oxygen-Sans, Ubuntu, Cantarell, &quot;Helvetica Neue&quot;, sans-serif;
#   color: hsl(0, 0%, 29%);
#   font-size: 1em;
#   font-weight: 400;
#   line-height: 1.5;
# }
#
# *,
# ::after,
# ::before {
#   box-sizing: inherit;
# }
#
# a {
#   color: rgb(0, 100, 200);
#   text-decoration: none;
# }
#
# a:hover {
#   text-decoration: underline;
# }
#
# a:visited {
#   color: rgb(0, 80, 160);
# }
# :root {
#   --ease-cubic-in-out: cubic-bezier(0.645, 0.045, 0.355, 1);
#
#   --md-red-50: hsl(350, 100.0%, 96.08%);
#   --md-red-100: hsl(354, 100.0%, 90.2%);
#   --md-red-200: hsl(0, 72.65%, 77.06%);
#   --md-red-300: hsl(0, 68.67%, 67.45%);
#   --md-red-400: hsl(1, 83.25%, 62.55%);
#   --md-red-500: hsl(4, 89.62%, 58.43%);
#   --md-red-600: hsl(1, 77.19%, 55.29%);
#   --md-red-700: hsl(0, 65.08%, 50.59%);
#   --md-red-800: hsl(0, 66.39%, 46.67%);
#   --md-red-900: hsl(0, 73.46%, 41.37%);
#   --md-red-a100: hsl(4, 100.0%, 75.1%);
#   --md-red-a200: hsl(0, 100.0%, 66.08%);
#   --md-red-a400: hsl(348, 100.0%, 54.51%);
#   --md-red-a700: hsl(0, 100.0%, 41.76%);
#
#   --md-pink-50: hsl(340, 80.0%, 94.12%);
#   --md-pink-100: hsl(339, 81.33%, 85.29%);
#   --md-pink-200: hsl(339, 82.11%, 75.88%);
#   --md-pink-300: hsl(339, 82.56%, 66.27%);
#   --md-pink-400: hsl(339, 81.9%, 58.82%);
#   --md-pink-500: hsl(339, 82.19%, 51.57%);
#   --md-pink-600: hsl(338, 77.78%, 47.65%);
#   --md-pink-700: hsl(336, 77.98%, 42.75%);
#   --md-pink-800: hsl(333, 79.27%, 37.84%);
#   --md-pink-900: hsl(328, 81.33%, 29.41%);
#   --md-pink-a100: hsl(339, 100.0%, 75.1%);
#   --md-pink-a200: hsl(339, 100.0%, 62.55%);
#   --md-pink-a400: hsl(338, 100.0%, 48.04%);
#   --md-pink-a700: hsl(333, 84.11%, 41.96%);
#
#   --md-purple-50: hsl(292, 44.44%, 92.94%);
#   --md-purple-100: hsl(291, 46.07%, 82.55%);
#   --md-purple-200: hsl(291, 46.94%, 71.18%);
#   --md-purple-300: hsl(291, 46.6%, 59.61%);
#   --md-purple-400: hsl(291, 46.61%, 50.78%);
#   --md-purple-500: hsl(291, 63.72%, 42.16%);
#   --md-purple-600: hsl(287, 65.05%, 40.39%);
#   --md-purple-700: hsl(282, 67.88%, 37.84%);
#   --md-purple-800: hsl(277, 70.17%, 35.49%);
#   --md-purple-900: hsl(267, 75.0%, 31.37%);
#   --md-purple-a100: hsl(291, 95.38%, 74.51%);
#   --md-purple-a200: hsl(291, 95.9%, 61.76%);
#   --md-purple-a400: hsl(291, 100.0%, 48.82%);
#   --md-purple-a700: hsl(280, 100.0%, 50.0%);
#
#   --md-deep-purple-50: hsl(264, 45.45%, 93.53%);
#   --md-deep-purple-100: hsl(261, 45.68%, 84.12%);
#   --md-deep-purple-200: hsl(261, 46.27%, 73.73%);
#   --md-deep-purple-300: hsl(261, 46.81%, 63.14%);
#   --md-deep-purple-400: hsl(261, 46.72%, 55.1%);
#   --md-deep-purple-500: hsl(261, 51.87%, 47.25%);
#   --md-deep-purple-600: hsl(259, 53.91%, 45.1%);
#   --md-deep-purple-700: hsl(257, 57.75%, 41.76%);
#   --md-deep-purple-800: hsl(254, 60.8%, 39.02%);
#   --md-deep-purple-900: hsl(251, 68.79%, 33.92%);
#   --md-deep-purple-a100: hsl(261, 100.0%, 76.67%);
#   --md-deep-purple-a200: hsl(255, 100.0%, 65.1%);
#   --md-deep-purple-a400: hsl(258, 100.0%, 56.08%);
#   --md-deep-purple-a700: hsl(265, 100.0%, 45.88%);
#
#   --md-indigo-50: hsl(231, 43.75%, 93.73%);
#   --md-indigo-100: hsl(231, 45.0%, 84.31%);
#   --md-indigo-200: hsl(230, 44.36%, 73.92%);
#   --md-indigo-300: hsl(230, 44.09%, 63.53%);
#   --md-indigo-400: hsl(230, 44.25%, 55.69%);
#   --md-indigo-500: hsl(230, 48.36%, 47.84%);
#   --md-indigo-600: hsl(231, 50.0%, 44.71%);
#   --md-indigo-700: hsl(231, 53.62%, 40.59%);
#   --md-indigo-800: hsl(232, 57.22%, 36.67%);
#   --md-indigo-900: hsl(234, 65.79%, 29.8%);
#   --md-indigo-a100: hsl(230, 100.0%, 77.45%);
#   --md-indigo-a200: hsl(230, 98.84%, 66.08%);
#   --md-indigo-a400: hsl(230, 98.97%, 61.76%);
#   --md-indigo-a700: hsl(230, 99.04%, 59.22%);
#
#   --md-blue-50: hsl(205, 86.67%, 94.12%);
#   --md-blue-100: hsl(207, 88.89%, 85.88%);
#   --md-blue-200: hsl(206, 89.74%, 77.06%);
#   --md-blue-300: hsl(206, 89.02%, 67.84%);
#   --md-blue-400: hsl(206, 89.95%, 60.98%);
#   --md-blue-500: hsl(206, 89.74%, 54.12%);
#   --md-blue-600: hsl(208, 79.28%, 50.78%);
#   --md-blue-700: hsl(209, 78.72%, 46.08%);
#   --md-blue-800: hsl(211, 80.28%, 41.76%);
#   --md-blue-900: hsl(216, 85.06%, 34.12%);
#   --md-blue-a100: hsl(217, 100.0%, 75.49%);
#   --md-blue-a200: hsl(217, 100.0%, 63.33%);
#   --md-blue-a400: hsl(217, 100.0%, 58.04%);
#   --md-blue-a700: hsl(224, 100.0%, 58.04%);
#
#   --md-light-blue-50: hsl(198, 93.55%, 93.92%);
#   --md-light-blue-100: hsl(198, 92.41%, 84.51%);
#   --md-light-blue-200: hsl(198, 92.37%, 74.31%);
#   --md-light-blue-300: hsl(198, 91.3%, 63.92%);
#   --md-light-blue-400: hsl(198, 91.93%, 56.27%);
#   --md-light-blue-500: hsl(198, 97.57%, 48.43%);
#   --md-light-blue-600: hsl(199, 97.41%, 45.49%);
#   --md-light-blue-700: hsl(201, 98.1%, 41.37%);
#   --md-light-blue-800: hsl(202, 97.91%, 37.45%);
#   --md-light-blue-900: hsl(206, 98.72%, 30.59%);
#   --md-light-blue-a100: hsl(198, 100.0%, 75.1%);
#   --md-light-blue-a200: hsl(198, 100.0%, 62.55%);
#   --md-light-blue-a400: hsl(198, 100.0%, 50.0%);
#   --md-light-blue-a700: hsl(202, 100.0%, 45.88%);
#
#   --md-cyan-50: hsl(186, 72.22%, 92.94%);
#   --md-cyan-100: hsl(186, 71.11%, 82.35%);
#   --md-cyan-200: hsl(186, 71.62%, 70.98%);
#   --md-cyan-300: hsl(186, 71.15%, 59.22%);
#   --md-cyan-400: hsl(186, 70.87%, 50.2%);
#   --md-cyan-500: hsl(186, 100.0%, 41.57%);
#   --md-cyan-600: hsl(186, 100.0%, 37.84%);
#   --md-cyan-700: hsl(185, 100.0%, 32.75%);
#   --md-cyan-800: hsl(185, 100.0%, 28.04%);
#   --md-cyan-900: hsl(182, 100.0%, 19.61%);
#   --md-cyan-a100: hsl(180, 100.0%, 75.88%);
#   --md-cyan-a200: hsl(180, 100.0%, 54.71%);
#   --md-cyan-a400: hsl(186, 100.0%, 50.0%);
#   --md-cyan-a700: hsl(187, 100.0%, 41.57%);
#
#   --md-teal-50: hsl(176, 40.91%, 91.37%);
#   --md-teal-100: hsl(174, 41.28%, 78.63%);
#   --md-teal-200: hsl(174, 41.9%, 64.9%);
#   --md-teal-300: hsl(174, 41.83%, 50.78%);
#   --md-teal-400: hsl(174, 62.75%, 40.0%);
#   --md-teal-500: hsl(174, 100.0%, 29.41%);
#   --md-teal-600: hsl(173, 100.0%, 26.86%);
#   --md-teal-700: hsl(173, 100.0%, 23.73%);
#   --md-teal-800: hsl(172, 100.0%, 20.59%);
#   --md-teal-900: hsl(169, 100.0%, 15.1%);
#   --md-teal-a100: hsl(166, 100.0%, 82.75%);
#   --md-teal-a200: hsl(165, 100.0%, 69.61%);
#   --md-teal-a400: hsl(165, 82.26%, 51.37%);
#   --md-teal-a700: hsl(171, 100.0%, 37.45%);
#
#   --md-green-50: hsl(124, 39.39%, 93.53%);
#   --md-green-100: hsl(121, 37.5%, 84.31%);
#   --md-green-200: hsl(122, 37.4%, 74.31%);
#   --md-green-300: hsl(122, 38.46%, 64.31%);
#   --md-green-400: hsl(122, 38.46%, 56.67%);
#   --md-green-500: hsl(122, 39.44%, 49.22%);
#   --md-green-600: hsl(122, 40.97%, 44.51%);
#   --md-green-700: hsl(122, 43.43%, 38.82%);
#   --md-green-800: hsl(123, 46.2%, 33.53%);
#   --md-green-900: hsl(124, 55.37%, 23.73%);
#   --md-green-a100: hsl(136, 77.22%, 84.51%);
#   --md-green-a200: hsl(150, 81.82%, 67.65%);
#   --md-green-a400: hsl(150, 100.0%, 45.1%);
#   --md-green-a700: hsl(144, 100.0%, 39.22%);
#
#   --md-light-green-50: hsl(88, 51.72%, 94.31%);
#   --md-light-green-100: hsl(87, 50.68%, 85.69%);
#   --md-light-green-200: hsl(88, 50.0%, 76.47%);
#   --md-light-green-300: hsl(87, 50.0%, 67.06%);
#   --md-light-green-400: hsl(87, 50.24%, 59.8%);
#   --md-light-green-500: hsl(87, 50.21%, 52.75%);
#   --md-light-green-600: hsl(89, 46.12%, 48.04%);
#   --md-light-green-700: hsl(92, 47.91%, 42.16%);
#   --md-light-green-800: hsl(95, 49.46%, 36.47%);
#   --md-light-green-900: hsl(103, 55.56%, 26.47%);
#   --md-light-green-a100: hsl(87, 100.0%, 78.24%);
#   --md-light-green-a200: hsl(87, 100.0%, 67.45%);
#   --md-

# %% [markdown]
# ## 4. Multiple Instances
#
# Sometimes it is helpful to compare multiple instances of the same VA tool (e.g., with different data or configurations) side by side. If we are running this notebook in JupyterLab, Jupyter Lite, or Jupyter Notebook > 4.0, we can use [StickyLand](https://github.com/xiaohk/stickyland) to do that. We can even create a dashoboard to mix and match different VA tools!

# %% [markdown]
# <img src="https://i.imgur.com/XhYD2hl.png" width="1400px" />
