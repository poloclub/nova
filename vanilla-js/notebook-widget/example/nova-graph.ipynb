# %%
import novagraph as nova
from json import load

# %% [markdown]
# ## 1. Visual Analytics in Notebooks
#
# We can directly use `nova.visualize()` to visualize a graph (loaded from a JSON file) with default configurations.

# %%
# Read the data
miserables = load(open('./miserables.json', 'r'))

# Pass data to our VA tool and show it below the cell
nova.visualize(miserables)
# Out:
#         <iframe
#             srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html lang=&quot;en&quot;&gt;
#     &lt;head&gt;
#         &lt;meta charset=&quot;UTF-8&quot; /&gt;
#         &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot; /&gt;
#         &lt;title&gt;Vanilla nova&lt;/title&gt;
#         &lt;script src=&quot;https://d3js.org/d3.v7.min.js&quot;&gt;&lt;/script&gt;
#
#         &lt;style&gt;.main-app {  display: flex;  align-items: center;  height: calc(100vh - 5px);  max-height: 800px;  width: 100vw;  box-sizing: border-box;  overflow-x: hidden;  position: relative;  background-color: white;}.main-app.notebook {  max-height: unset;}.top-grid {  width: 100%;  display: grid;  grid-template-columns: [start] 1fr [mid-start] auto [mid-end] 1fr [end];  align-items: center;}.graph-container {  grid-column: mid-start / mid-end;  display: flex;  align-items: center;}.graph-container.left-align {  grid-column: start / mid-start;}.dataset-container {  grid-column: start / mid-start;  width: 100%;  height: 100%;  padding-top: 10px;  padding-right: 20px;  display: flex;  flex-direction: column;  justify-content: flex-start;  align-items: flex-end;  gap: 8px;}.dataset-title {  font-weight: 600;  margin-bottom: 2px;}.dataset-option {  font-size: 0.92rem;  font-variant: small-caps;  color: var(--md-gray-700);  border-bottom: 1px solid transparent;  cursor: pointer;  line-height: 1;}.dataset-option.selected {  border-bottom: 1px solid var(--md-gray-400);}.parameter-wrapper {  width: 190px;  display: flex;  flex-direction: column;  align-items: center;  font-size: 0.9rem;  padding: 5px 12px 8px 12px;}.parameter-title {  border-bottom: 1px solid var(--md-gray-300);  margin-bottom: 10px;  font-weight: 600;  font-size: 1rem;  width: 100%;  display: flex;  justify-content: space-around;  align-items: center;  line-height: 0;  padding: 10px 0;}.parameter-title .svg-icon {  display: flex;  justify-content: center;  align-items: center;  color: var(--md-gray-700);  padding-top: 0px;  cursor: pointer;}.parameter-title .svg-icon:hover {  color: var(--md-gray-900);}.parameter-title .svg-icon svg {  margin-top: 1px;  width: 1rem;  height: 1rem;  fill: currentColor;}.parameter-item {  display: flex;  flex-direction: column;  align-items: center;  width: 100%;}.parameter {  width: 100%;  display: flex;  flex-direction: row;  justify-content: space-between;  align-items: center;  gap: 3px;}.parameter .parameter-value {  background-color: var(--md-indigo-50);  line-height: 1;  padding: 2px 3px;  border-radius: 2px;  font-variant-numeric: tabular-nums;}.slider {  width: 100%;}.graph-wrapper {  background-color: var(--md-gray-50);  border: 1px solid var(--md-gray-300);  border-radius: 8px;  position: relative;  aspect-ratio: 1 / 1;}.graph-footer {  position: absolute;  left: 0px;  bottom: 0px;  padding: 2px 8px;  border-top-right-radius: 5px;  background-color: hsla(0, 0%, 98.04%, 0.5);  color: var(--md-gray-700);  font-size: 0.9rem;  cursor: default;  display: flex;  justify-content: space-between;  width: 100%;}.graph-footer a .name {  color: var(--md-gray-400);}.graph-footer a .name svg {  fill: currentColor;  height: 12px;}.config-container {  position: absolute;  right: 0px;  top: 15px;  transform: translateX(calc(100% - 3px));  box-shadow: 0px 0px 1px 0px hsla(0, 0%, 0%, 0.07),    0px 0px 5px 0px hsla(0, 0%, 0%, 0.12);  border-radius: 5px;  background-color: white;  animation: fade-in 150ms ease-in-out;}.config-container.no-display {  display: none;}.config-button {  position: absolute;  top: 10px;  right: 10px;  color: var(--md-gray-600);  background-color: hsla(0, 0%, 98.04%, 0.5);  border-radius: 3px;  padding: 4px;  line-height: 1;  cursor: pointer;  display: flex;  justify-content: center;  align-items: center;  transition: color 100ms ease-in-out, background-color 100ms ease-in-out;  animation: fade-in 150ms ease-in-out;}.config-button svg {  fill: currentColor;  width: 1.2rem;  height: 1.2rem;}.config-button:hover {  color: var(--md-gray-800);}.config-button:active {  color: var(--md-gray-900);}.config-button.selected {  color: var(--md-gray-800);  background-color: hsla(0, 0%, 86%, 0.5);}.config-button svg {  fill: currentColor;  width: 1.2rem;  height: 1.2rem;}@keyframes fade-in {  from {    opacity: 0;  }  to {    opacity: 1;  }}html {  font-size: 16px;  -moz-osx-font-smoothing: grayscale;  -webkit-font-smooth ...

# %% [markdown]
# ## 2. Customized Visual Analytics
#
# We can also pass argumetns into `nova.visualize()` to create a customized VA tool. We can control the size of the graph view and initial force layout strengths.
#
# Run `?nova.visualize` to see all parameters.

# %%
# ?nova.visualize

# %%
nova.visualize(miserables, width=400, height=420, node_strength=-20)
# Out:
#         <iframe
#             srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html lang=&quot;en&quot;&gt;
#     &lt;head&gt;
#         &lt;meta charset=&quot;UTF-8&quot; /&gt;
#         &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot; /&gt;
#         &lt;title&gt;Vanilla nova&lt;/title&gt;
#         &lt;script src=&quot;https://d3js.org/d3.v7.min.js&quot;&gt;&lt;/script&gt;
#
#         &lt;style&gt;.main-app {  display: flex;  align-items: center;  height: calc(100vh - 5px);  max-height: 800px;  width: 100vw;  box-sizing: border-box;  overflow-x: hidden;  position: relative;  background-color: white;}.main-app.notebook {  max-height: unset;}.top-grid {  width: 100%;  display: grid;  grid-template-columns: [start] 1fr [mid-start] auto [mid-end] 1fr [end];  align-items: center;}.graph-container {  grid-column: mid-start / mid-end;  display: flex;  align-items: center;}.graph-container.left-align {  grid-column: start / mid-start;}.dataset-container {  grid-column: start / mid-start;  width: 100%;  height: 100%;  padding-top: 10px;  padding-right: 20px;  display: flex;  flex-direction: column;  justify-content: flex-start;  align-items: flex-end;  gap: 8px;}.dataset-title {  font-weight: 600;  margin-bottom: 2px;}.dataset-option {  font-size: 0.92rem;  font-variant: small-caps;  color: var(--md-gray-700);  border-bottom: 1px solid transparent;  cursor: pointer;  line-height: 1;}.dataset-option.selected {  border-bottom: 1px solid var(--md-gray-400);}.parameter-wrapper {  width: 190px;  display: flex;  flex-direction: column;  align-items: center;  font-size: 0.9rem;  padding: 5px 12px 8px 12px;}.parameter-title {  border-bottom: 1px solid var(--md-gray-300);  margin-bottom: 10px;  font-weight: 600;  font-size: 1rem;  width: 100%;  display: flex;  justify-content: space-around;  align-items: center;  line-height: 0;  padding: 10px 0;}.parameter-title .svg-icon {  display: flex;  justify-content: center;  align-items: center;  color: var(--md-gray-700);  padding-top: 0px;  cursor: pointer;}.parameter-title .svg-icon:hover {  color: var(--md-gray-900);}.parameter-title .svg-icon svg {  margin-top: 1px;  width: 1rem;  height: 1rem;  fill: currentColor;}.parameter-item {  display: flex;  flex-direction: column;  align-items: center;  width: 100%;}.parameter {  width: 100%;  display: flex;  flex-direction: row;  justify-content: space-between;  align-items: center;  gap: 3px;}.parameter .parameter-value {  background-color: var(--md-indigo-50);  line-height: 1;  padding: 2px 3px;  border-radius: 2px;  font-variant-numeric: tabular-nums;}.slider {  width: 100%;}.graph-wrapper {  background-color: var(--md-gray-50);  border: 1px solid var(--md-gray-300);  border-radius: 8px;  position: relative;  aspect-ratio: 1 / 1;}.graph-footer {  position: absolute;  left: 0px;  bottom: 0px;  padding: 2px 8px;  border-top-right-radius: 5px;  background-color: hsla(0, 0%, 98.04%, 0.5);  color: var(--md-gray-700);  font-size: 0.9rem;  cursor: default;  display: flex;  justify-content: space-between;  width: 100%;}.graph-footer a .name {  color: var(--md-gray-400);}.graph-footer a .name svg {  fill: currentColor;  height: 12px;}.config-container {  position: absolute;  right: 0px;  top: 15px;  transform: translateX(calc(100% - 3px));  box-shadow: 0px 0px 1px 0px hsla(0, 0%, 0%, 0.07),    0px 0px 5px 0px hsla(0, 0%, 0%, 0.12);  border-radius: 5px;  background-color: white;  animation: fade-in 150ms ease-in-out;}.config-container.no-display {  display: none;}.config-button {  position: absolute;  top: 10px;  right: 10px;  color: var(--md-gray-600);  background-color: hsla(0, 0%, 98.04%, 0.5);  border-radius: 3px;  padding: 4px;  line-height: 1;  cursor: pointer;  display: flex;  justify-content: center;  align-items: center;  transition: color 100ms ease-in-out, background-color 100ms ease-in-out;  animation: fade-in 150ms ease-in-out;}.config-button svg {  fill: currentColor;  width: 1.2rem;  height: 1.2rem;}.config-button:hover {  color: var(--md-gray-800);}.config-button:active {  color: var(--md-gray-900);}.config-button.selected {  color: var(--md-gray-800);  background-color: hsla(0, 0%, 86%, 0.5);}.config-button svg {  fill: currentColor;  width: 1.2rem;  height: 1.2rem;}@keyframes fade-in {  from {    opacity: 0;  }  to {    opacity: 1;  }}html {  font-size: 16px;  -moz-osx-font-smoothing: grayscale;  -webkit-font-smooth ...

# %%
nova.visualize(miserables, width=800, height=820, node_strength=-90)
# Out:
#         <iframe
#             srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html lang=&quot;en&quot;&gt;
#     &lt;head&gt;
#         &lt;meta charset=&quot;UTF-8&quot; /&gt;
#         &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot; /&gt;
#         &lt;title&gt;Vanilla nova&lt;/title&gt;
#         &lt;script src=&quot;https://d3js.org/d3.v7.min.js&quot;&gt;&lt;/script&gt;
#
#         &lt;style&gt;.main-app {  display: flex;  align-items: center;  height: calc(100vh - 5px);  max-height: 800px;  width: 100vw;  box-sizing: border-box;  overflow-x: hidden;  position: relative;  background-color: white;}.main-app.notebook {  max-height: unset;}.top-grid {  width: 100%;  display: grid;  grid-template-columns: [start] 1fr [mid-start] auto [mid-end] 1fr [end];  align-items: center;}.graph-container {  grid-column: mid-start / mid-end;  display: flex;  align-items: center;}.graph-container.left-align {  grid-column: start / mid-start;}.dataset-container {  grid-column: start / mid-start;  width: 100%;  height: 100%;  padding-top: 10px;  padding-right: 20px;  display: flex;  flex-direction: column;  justify-content: flex-start;  align-items: flex-end;  gap: 8px;}.dataset-title {  font-weight: 600;  margin-bottom: 2px;}.dataset-option {  font-size: 0.92rem;  font-variant: small-caps;  color: var(--md-gray-700);  border-bottom: 1px solid transparent;  cursor: pointer;  line-height: 1;}.dataset-option.selected {  border-bottom: 1px solid var(--md-gray-400);}.parameter-wrapper {  width: 190px;  display: flex;  flex-direction: column;  align-items: center;  font-size: 0.9rem;  padding: 5px 12px 8px 12px;}.parameter-title {  border-bottom: 1px solid var(--md-gray-300);  margin-bottom: 10px;  font-weight: 600;  font-size: 1rem;  width: 100%;  display: flex;  justify-content: space-around;  align-items: center;  line-height: 0;  padding: 10px 0;}.parameter-title .svg-icon {  display: flex;  justify-content: center;  align-items: center;  color: var(--md-gray-700);  padding-top: 0px;  cursor: pointer;}.parameter-title .svg-icon:hover {  color: var(--md-gray-900);}.parameter-title .svg-icon svg {  margin-top: 1px;  width: 1rem;  height: 1rem;  fill: currentColor;}.parameter-item {  display: flex;  flex-direction: column;  align-items: center;  width: 100%;}.parameter {  width: 100%;  display: flex;  flex-direction: row;  justify-content: space-between;  align-items: center;  gap: 3px;}.parameter .parameter-value {  background-color: var(--md-indigo-50);  line-height: 1;  padding: 2px 3px;  border-radius: 2px;  font-variant-numeric: tabular-nums;}.slider {  width: 100%;}.graph-wrapper {  background-color: var(--md-gray-50);  border: 1px solid var(--md-gray-300);  border-radius: 8px;  position: relative;  aspect-ratio: 1 / 1;}.graph-footer {  position: absolute;  left: 0px;  bottom: 0px;  padding: 2px 8px;  border-top-right-radius: 5px;  background-color: hsla(0, 0%, 98.04%, 0.5);  color: var(--md-gray-700);  font-size: 0.9rem;  cursor: default;  display: flex;  justify-content: space-between;  width: 100%;}.graph-footer a .name {  color: var(--md-gray-400);}.graph-footer a .name svg {  fill: currentColor;  height: 12px;}.config-container {  position: absolute;  right: 0px;  top: 15px;  transform: translateX(calc(100% - 3px));  box-shadow: 0px 0px 1px 0px hsla(0, 0%, 0%, 0.07),    0px 0px 5px 0px hsla(0, 0%, 0%, 0.12);  border-radius: 5px;  background-color: white;  animation: fade-in 150ms ease-in-out;}.config-container.no-display {  display: none;}.config-button {  position: absolute;  top: 10px;  right: 10px;  color: var(--md-gray-600);  background-color: hsla(0, 0%, 98.04%, 0.5);  border-radius: 3px;  padding: 4px;  line-height: 1;  cursor: pointer;  display: flex;  justify-content: center;  align-items: center;  transition: color 100ms ease-in-out, background-color 100ms ease-in-out;  animation: fade-in 150ms ease-in-out;}.config-button svg {  fill: currentColor;  width: 1.2rem;  height: 1.2rem;}.config-button:hover {  color: var(--md-gray-800);}.config-button:active {  color: var(--md-gray-900);}.config-button.selected {  color: var(--md-gray-800);  background-color: hsla(0, 0%, 86%, 0.5);}.config-button svg {  fill: currentColor;  width: 1.2rem;  height: 1.2rem;}@keyframes fade-in {  from {    opacity: 0;  }  to {    opacity: 1;  }}html {  font-size: 16px;  -moz-osx-font-smoothing: grayscale;  -webkit-font-smooth ...

# %% [markdown]
# ## 3. Different Datasets
#
# We can pass different datasets into this simple VA tool through the first argument of `nova.visualize()`.

# %%
stackoverflow = load(open('./stackoverflow.json', 'r'))
nova.visualize(
    stackoverflow,
    width=400,
    height=420,
    node_strength=-10,
    link_strength=4
)
# Out:
#         <iframe
#             srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html lang=&quot;en&quot;&gt;
#     &lt;head&gt;
#         &lt;meta charset=&quot;UTF-8&quot; /&gt;
#         &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot; /&gt;
#         &lt;title&gt;Vanilla nova&lt;/title&gt;
#         &lt;script src=&quot;https://d3js.org/d3.v7.min.js&quot;&gt;&lt;/script&gt;
#
#         &lt;style&gt;.main-app {  display: flex;  align-items: center;  height: calc(100vh - 5px);  max-height: 800px;  width: 100vw;  box-sizing: border-box;  overflow-x: hidden;  position: relative;  background-color: white;}.main-app.notebook {  max-height: unset;}.top-grid {  width: 100%;  display: grid;  grid-template-columns: [start] 1fr [mid-start] auto [mid-end] 1fr [end];  align-items: center;}.graph-container {  grid-column: mid-start / mid-end;  display: flex;  align-items: center;}.graph-container.left-align {  grid-column: start / mid-start;}.dataset-container {  grid-column: start / mid-start;  width: 100%;  height: 100%;  padding-top: 10px;  padding-right: 20px;  display: flex;  flex-direction: column;  justify-content: flex-start;  align-items: flex-end;  gap: 8px;}.dataset-title {  font-weight: 600;  margin-bottom: 2px;}.dataset-option {  font-size: 0.92rem;  font-variant: small-caps;  color: var(--md-gray-700);  border-bottom: 1px solid transparent;  cursor: pointer;  line-height: 1;}.dataset-option.selected {  border-bottom: 1px solid var(--md-gray-400);}.parameter-wrapper {  width: 190px;  display: flex;  flex-direction: column;  align-items: center;  font-size: 0.9rem;  padding: 5px 12px 8px 12px;}.parameter-title {  border-bottom: 1px solid var(--md-gray-300);  margin-bottom: 10px;  font-weight: 600;  font-size: 1rem;  width: 100%;  display: flex;  justify-content: space-around;  align-items: center;  line-height: 0;  padding: 10px 0;}.parameter-title .svg-icon {  display: flex;  justify-content: center;  align-items: center;  color: var(--md-gray-700);  padding-top: 0px;  cursor: pointer;}.parameter-title .svg-icon:hover {  color: var(--md-gray-900);}.parameter-title .svg-icon svg {  margin-top: 1px;  width: 1rem;  height: 1rem;  fill: currentColor;}.parameter-item {  display: flex;  flex-direction: column;  align-items: center;  width: 100%;}.parameter {  width: 100%;  display: flex;  flex-direction: row;  justify-content: space-between;  align-items: center;  gap: 3px;}.parameter .parameter-value {  background-color: var(--md-indigo-50);  line-height: 1;  padding: 2px 3px;  border-radius: 2px;  font-variant-numeric: tabular-nums;}.slider {  width: 100%;}.graph-wrapper {  background-color: var(--md-gray-50);  border: 1px solid var(--md-gray-300);  border-radius: 8px;  position: relative;  aspect-ratio: 1 / 1;}.graph-footer {  position: absolute;  left: 0px;  bottom: 0px;  padding: 2px 8px;  border-top-right-radius: 5px;  background-color: hsla(0, 0%, 98.04%, 0.5);  color: var(--md-gray-700);  font-size: 0.9rem;  cursor: default;  display: flex;  justify-content: space-between;  width: 100%;}.graph-footer a .name {  color: var(--md-gray-400);}.graph-footer a .name svg {  fill: currentColor;  height: 12px;}.config-container {  position: absolute;  right: 0px;  top: 15px;  transform: translateX(calc(100% - 3px));  box-shadow: 0px 0px 1px 0px hsla(0, 0%, 0%, 0.07),    0px 0px 5px 0px hsla(0, 0%, 0%, 0.12);  border-radius: 5px;  background-color: white;  animation: fade-in 150ms ease-in-out;}.config-container.no-display {  display: none;}.config-button {  position: absolute;  top: 10px;  right: 10px;  color: var(--md-gray-600);  background-color: hsla(0, 0%, 98.04%, 0.5);  border-radius: 3px;  padding: 4px;  line-height: 1;  cursor: pointer;  display: flex;  justify-content: center;  align-items: center;  transition: color 100ms ease-in-out, background-color 100ms ease-in-out;  animation: fade-in 150ms ease-in-out;}.config-button svg {  fill: currentColor;  width: 1.2rem;  height: 1.2rem;}.config-button:hover {  color: var(--md-gray-800);}.config-button:active {  color: var(--md-gray-900);}.config-button.selected {  color: var(--md-gray-800);  background-color: hsla(0, 0%, 86%, 0.5);}.config-button svg {  fill: currentColor;  width: 1.2rem;  height: 1.2rem;}@keyframes fade-in {  from {    opacity: 0;  }  to {    opacity: 1;  }}html {  font-size: 16px;  -moz-osx-font-smoothing: grayscale;  -webkit-font-smooth ...

# %%
karate = load(open('./karate.json', 'r'))
nova.visualize(karate, width=400, height=420, node_strength=-5)
# Out:
#         <iframe
#             srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html lang=&quot;en&quot;&gt;
#     &lt;head&gt;
#         &lt;meta charset=&quot;UTF-8&quot; /&gt;
#         &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot; /&gt;
#         &lt;title&gt;Vanilla nova&lt;/title&gt;
#         &lt;script src=&quot;https://d3js.org/d3.v7.min.js&quot;&gt;&lt;/script&gt;
#
#         &lt;style&gt;.main-app {  display: flex;  align-items: center;  height: calc(100vh - 5px);  max-height: 800px;  width: 100vw;  box-sizing: border-box;  overflow-x: hidden;  position: relative;  background-color: white;}.main-app.notebook {  max-height: unset;}.top-grid {  width: 100%;  display: grid;  grid-template-columns: [start] 1fr [mid-start] auto [mid-end] 1fr [end];  align-items: center;}.graph-container {  grid-column: mid-start / mid-end;  display: flex;  align-items: center;}.graph-container.left-align {  grid-column: start / mid-start;}.dataset-container {  grid-column: start / mid-start;  width: 100%;  height: 100%;  padding-top: 10px;  padding-right: 20px;  display: flex;  flex-direction: column;  justify-content: flex-start;  align-items: flex-end;  gap: 8px;}.dataset-title {  font-weight: 600;  margin-bottom: 2px;}.dataset-option {  font-size: 0.92rem;  font-variant: small-caps;  color: var(--md-gray-700);  border-bottom: 1px solid transparent;  cursor: pointer;  line-height: 1;}.dataset-option.selected {  border-bottom: 1px solid var(--md-gray-400);}.parameter-wrapper {  width: 190px;  display: flex;  flex-direction: column;  align-items: center;  font-size: 0.9rem;  padding: 5px 12px 8px 12px;}.parameter-title {  border-bottom: 1px solid var(--md-gray-300);  margin-bottom: 10px;  font-weight: 600;  font-size: 1rem;  width: 100%;  display: flex;  justify-content: space-around;  align-items: center;  line-height: 0;  padding: 10px 0;}.parameter-title .svg-icon {  display: flex;  justify-content: center;  align-items: center;  color: var(--md-gray-700);  padding-top: 0px;  cursor: pointer;}.parameter-title .svg-icon:hover {  color: var(--md-gray-900);}.parameter-title .svg-icon svg {  margin-top: 1px;  width: 1rem;  height: 1rem;  fill: currentColor;}.parameter-item {  display: flex;  flex-direction: column;  align-items: center;  width: 100%;}.parameter {  width: 100%;  display: flex;  flex-direction: row;  justify-content: space-between;  align-items: center;  gap: 3px;}.parameter .parameter-value {  background-color: var(--md-indigo-50);  line-height: 1;  padding: 2px 3px;  border-radius: 2px;  font-variant-numeric: tabular-nums;}.slider {  width: 100%;}.graph-wrapper {  background-color: var(--md-gray-50);  border: 1px solid var(--md-gray-300);  border-radius: 8px;  position: relative;  aspect-ratio: 1 / 1;}.graph-footer {  position: absolute;  left: 0px;  bottom: 0px;  padding: 2px 8px;  border-top-right-radius: 5px;  background-color: hsla(0, 0%, 98.04%, 0.5);  color: var(--md-gray-700);  font-size: 0.9rem;  cursor: default;  display: flex;  justify-content: space-between;  width: 100%;}.graph-footer a .name {  color: var(--md-gray-400);}.graph-footer a .name svg {  fill: currentColor;  height: 12px;}.config-container {  position: absolute;  right: 0px;  top: 15px;  transform: translateX(calc(100% - 3px));  box-shadow: 0px 0px 1px 0px hsla(0, 0%, 0%, 0.07),    0px 0px 5px 0px hsla(0, 0%, 0%, 0.12);  border-radius: 5px;  background-color: white;  animation: fade-in 150ms ease-in-out;}.config-container.no-display {  display: none;}.config-button {  position: absolute;  top: 10px;  right: 10px;  color: var(--md-gray-600);  background-color: hsla(0, 0%, 98.04%, 0.5);  border-radius: 3px;  padding: 4px;  line-height: 1;  cursor: pointer;  display: flex;  justify-content: center;  align-items: center;  transition: color 100ms ease-in-out, background-color 100ms ease-in-out;  animation: fade-in 150ms ease-in-out;}.config-button svg {  fill: currentColor;  width: 1.2rem;  height: 1.2rem;}.config-button:hover {  color: var(--md-gray-800);}.config-button:active {  color: var(--md-gray-900);}.config-button.selected {  color: var(--md-gray-800);  background-color: hsla(0, 0%, 86%, 0.5);}.config-button svg {  fill: currentColor;  width: 1.2rem;  height: 1.2rem;}@keyframes fade-in {  from {    opacity: 0;  }  to {    opacity: 1;  }}html {  font-size: 16px;  -moz-osx-font-smoothing: grayscale;  -webkit-font-smooth ...

# %% [markdown]
# ## 4. Multiple Instances
#
# Sometimes it is helpful to compare multiple instances of the same VA tool (e.g., with different data or configurations) side by side. If we are running this notebook in JupyterLab, Jupyter Lite, or Jupyter Notebook > 4.0, we can use [StickyLand](https://github.com/xiaohk/stickyland) to do that. We can even create a dashoboard to mix and match different VA tools!

# %% [markdown]
# <img src="https://i.imgur.com/XhYD2hl.png" width="1400px" />
